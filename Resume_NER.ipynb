# %%
import numpy as np
import pandas as pd
import os
import json
import re

# %%
def convert_dataturks_to_spacy(dataturks_JSON_FilePath):
    training_data = []
    lines = []
    with open(dataturks_JSON_FilePath, 'r') as f:
        lines = f.readlines()
    
    for line in lines:
        data = json.loads(line)
        text = data['content'].replace("\n",' ')
        entities = []
        data_annotations = data['annotation']
        if data_annotations is not None:
            for annotations in data_annotations:
                point = annotations['points'][0]
                labels = annotations['label']
                if not isinstance(labels, list):
                    labels = [labels]
                
                for label in labels:
                    point_start = point['start']
                    point_end = point['end']
                    point_text = point['text']
                    
                    lstrip_diff = len(point_text) - len(point_text.lstrip())
                    rstrip_diff = len(point_text) - len(point_text.rstrip())
                    if lstrip_diff != 0:
                        point_start = point_start + lstrip_diff
                    if rstrip_diff != 0:
                        point_end = point_end - rstrip_diff
                    
                    entities.append((point_start, point_end + 1, label))
                    
        training_data.append((text, {"entities": entities}))
    return training_data

# %%
training_data = convert_dataturks_to_spacy("./Entity Recognition in Resumes.json")

# %%
training_data[0]
# Out:
# ("Abhishek Jha Application Development Associate - Accenture  Bengaluru, Karnataka - Email me on Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a  • To work for an organization which provides me the opportunity to improve my skills and knowledge for my individual and company's growth in best possible ways.  Willing to relocate to: Bangalore, Karnataka  WORK EXPERIENCE  Application Development Associate  Accenture -  November 2017 to Present  Role: Currently working on Chat-bot. Developing Backend Oracle PeopleSoft Queries for the Bot which will be triggered based on given input. Also, Training the bot for different possible utterances (Both positive and negative), which will be given as input by the user.  EDUCATION  B.E in Information science and engineering  B.v.b college of engineering and technology -  Hubli, Karnataka  August 2013 to June 2017  12th in Mathematics  Woodbine modern school  April 2011 to March 2013  10th  Kendriya Vidyalaya  April 2001 to March 2011  SKILLS  C (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year), Database Management System (Less than 1 year), Java (Less than 1 year)  ADDITIONAL INFORMATION  Technical Skills  https://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN   • Programming language: C, C++, Java • Oracle PeopleSoft • Internet Of Things • Machine Learning • Database Management System • Computer Networks • Operating System worked on: Linux, Windows, Mac  Non - Technical Skills  • Honest and Hard-Working • Tolerant and Flexible to Different Situations • Polite and Calm • Team-Player",
#  {'entities': [(1296, 1622, 'Skills'),
#    (993, 1154, 'Skills'),
#    (939, 957, 'College Name'),
#    (883, 905, 'College Name'),
#    (856, 860, 'Graduation Year'),
#    (771, 814, 'College Name'),
#    (727, 769, 'Designation'),
#    (407, 416, 'Companies worked at'),
#    (372, 405, 'Designation'),
#    (95, 145, 'Email Address'),
#    (60, 69, 'Location'),
#    (49, 58, 'Companies worked at'),
#    (13, 46, 'Designation'),
#    (0, 12, 'Name')]})

# %%
def trim_entity_spans(data: list) -> list:
    """Removes leading and trailing white spaces from entity spans.

    Args:
        data (list): The data to be cleaned in spaCy JSON format.

    Returns:
        list: The cleaned data.
    """
    invalid_span_tokens = re.compile(r"\s")
    cleaned_data = []
    for text, annotations in data:
        entities = annotations['entities']
        valid_entities = []
        for start, end, label in entities:
            valid_start = start
            valid_end = end
            while valid_start < len(text) and invalid_span_tokens.match(
                    text[valid_start]):
                valid_start += 1
            while valid_end > 1 and invalid_span_tokens.match(
                    text[valid_end - 1]):
                valid_end -= 1
            valid_entities.append([valid_start, valid_end, label])
        cleaned_data.append([text, {'entities': valid_entities}])
    return cleaned_data

# %%
data = trim_entity_spans(training_data)

# %%
data[0]
# Out:
# ["Abhishek Jha Application Development Associate - Accenture  Bengaluru, Karnataka - Email me on Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a  • To work for an organization which provides me the opportunity to improve my skills and knowledge for my individual and company's growth in best possible ways.  Willing to relocate to: Bangalore, Karnataka  WORK EXPERIENCE  Application Development Associate  Accenture -  November 2017 to Present  Role: Currently working on Chat-bot. Developing Backend Oracle PeopleSoft Queries for the Bot which will be triggered based on given input. Also, Training the bot for different possible utterances (Both positive and negative), which will be given as input by the user.  EDUCATION  B.E in Information science and engineering  B.v.b college of engineering and technology -  Hubli, Karnataka  August 2013 to June 2017  12th in Mathematics  Woodbine modern school  April 2011 to March 2013  10th  Kendriya Vidyalaya  April 2001 to March 2011  SKILLS  C (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year), Database Management System (Less than 1 year), Java (Less than 1 year)  ADDITIONAL INFORMATION  Technical Skills  https://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN   • Programming language: C, C++, Java • Oracle PeopleSoft • Internet Of Things • Machine Learning • Database Management System • Computer Networks • Operating System worked on: Linux, Windows, Mac  Non - Technical Skills  • Honest and Hard-Working • Tolerant and Flexible to Different Situations • Polite and Calm • Team-Player",
#  {'entities': [[1296, 1622, 'Skills'],
#    [993, 1154, 'Skills'],
#    [939, 957, 'College Name'],
#    [883, 905, 'College Name'],
#    [856, 860, 'Graduation Year'],
#    [771, 814, 'College Name'],
#    [727, 769, 'Designation'],
#    [407, 416, 'Companies worked at'],
#    [372, 405, 'Designation'],
#    [95, 145, 'Email Address'],
#    [60, 69, 'Location'],
#    [49, 58, 'Companies worked at'],
#    [13, 46, 'Designation'],
#    [0, 12, 'Name']]}]

# %% [markdown]
# ### Overlapping Entities

# %%
def clean_entities(training_data):
    
    clean_data = []
    for text, annotation in training_data:
        entities = annotation.get('entities')
        entities_copy = entities.copy()
        
        # append entity only if it is longer than its overlapping entity
        i = 0
        for entity in entities_copy:
            j = 0
            for overlapping_entity in entities_copy:
                # Skip self
                if i != j:
                    e_start, e_end, oe_start, oe_end = entity[0], entity[1], overlapping_entity[0], overlapping_entity[1]
                    # Delete any entity that overlaps, keep if longer
                    if ((e_start >= oe_start and e_start <= oe_end) or (e_end <= oe_end and e_end >= oe_start)) \
                    and ((e_end - e_start) <= (oe_end - oe_start)):
                        entities.remove(entity)
                j += 1
            i += 1
        clean_data.append((text, {'entities': entities}))
                
    return clean_data

# %%
data = clean_entities(data)

# %% [markdown]
# ### Entity Mapping

# %%
import spacy
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
from spacy.lang.en import English
from spacy.training import offsets_to_biluo_tags

# %%
def bilou_tags(data):
    docs = []
    annots = []
    nlp = English()
    for text, annotations in data:
        offsets = annotations['entities']
        doc = nlp(text)
        tags = offsets_to_biluo_tags(doc, offsets)
        docs.append([token.text for token in doc])
        annots.append(tags)
    df_data = pd.DataFrame({'docs':docs, 'annots':annots})
    return df_data

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df_data = bilou_tags(data)
df_data.head(5)
# Out:
#                                                 docs  \
# 0  [Abhishek, Jha, Application, Development, Asso...
# 1  [Afreen, Jamadar, Active, member, of, IIIT, Co...
# 2  [Akhil, Yadav, Polemaina, Hyderabad, ,, Telang...
# 3  [Alok, Khandai, Operational, Analyst, (, SQL, ...
# 4  [Ananya, Chavan, lecturer, -, oracle, tutorial...
#
#                                               annots
# 0  [B-Name, L-Name, B-Designation, I-Designation,...
# 1  [B-Name, L-Name, O, O, O, O, O, O, O, O, O, U-...
# 2  [B-Name, I-Name, L-Name, U-Location, O, O, O, ...
# 3  [B-Name, L-Name, B-Designation, I-Designation,...
# 4  [B-Name, L-Name, U-Designation, O, B-Companies...

# %%
df_data.shape
# Out:
# (220, 2)

# %% [markdown]
# ### Removing Mislabeled Examples

# %%
for i in range(len(df_data)):
    if "-" in df_data.loc[i, "annots"]:
        df_data.drop(i, axis='index', inplace=True)
df_data.reset_index(inplace=True)
df_data.shape
# Out:
# (110, 3)

# %%
spacy_data = []

for i in range(len(df_data)):
    resume = df_data.loc[i, "docs"]
    annots = df_data.loc[i, "annots"]
    example = []
    for word, annot in zip(resume, annots):
        if not(word.isalnum() or len(word) > 1):
            annot = "O"
        example.append((word, annot))
    spacy_data.append(example)
spacy_data[0]
# Out:
# [('Abhishek', 'B-Name'),
#  ('Jha', 'L-Name'),
#  ('Application', 'B-Designation'),
#  ('Development', 'I-Designation'),
#  ('Associate', 'L-Designation'),
#  ('-', 'O'),
#  ('Accenture', 'U-Companies worked at'),
#  (' ', 'O'),
#  ('Bengaluru', 'U-Location'),
#  (',', 'O'),
#  ('Karnataka', 'O'),
#  ('-', 'O'),
#  ('Email', 'O'),
#  ('me', 'O'),
#  ('on', 'O'),
#  ('Indeed', 'B-Email Address'),
#  (':', 'O'),
#  ('indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a', 'L-Email Address'),
#  (' ', 'O'),
#  ('•', 'O'),
#  ('To', 'O'),
#  ('work', 'O'),
#  ('for', 'O'),
#  ('an', 'O'),
#  ('organization', 'O'),
#  ('which', 'O'),
#  ('provides', 'O'),
#  ('me', 'O'),
#  ('the', 'O'),
#  ('opportunity', 'O'),
#  ('to', 'O'),
#  ('improve', 'O'),
#  ('my', 'O'),
#  ('skills', 'O'),
#  ('and', 'O'),
#  ('knowledge', 'O'),
#  ('for', 'O'),
#  ('my', 'O'),
#  ('individual', 'O'),
#  ('and', 'O'),
#  ('company', 'O'),
#  ("'s", 'O'),
#  ('growth', 'O'),
#  ('in', 'O'),
#  ('best', 'O'),
#  ('possible', 'O'),
#  ('ways', 'O'),
#  ('.', 'O'),
#  (' ', 'O'),
#  ('Willing', 'O'),
#  ('to', 'O'),
#  ('relocate', 'O'),
#  ('to', 'O'),
#  (':', 'O'),
#  ('Bangalore', 'O'),
#  (',', 'O'),
#  ('Karnataka', 'O'),
#  (' ', 'O'),
#  ('WORK', 'O'),
#  ('EXPERIENCE', 'O'),
#  (' ', 'O'),
#  ('Application', 'B-Designation'),
#  ('Development', 'I-Designation'),
#  ('Associate', 'L-Designation'),
#  (' ', 'O'),
#  ('Accenture', 'U-Companies worked at'),
#  ('-', 'O'),
#  (' ', 'O'),
#  ('November', 'O'),
#  ('2017', 'O'),
#  ('to', 'O'),
#  ('Present', 'O'),
#  (' ', 'O'),
#  ('Role', 'O'),
#  (':', 'O'),
#  ('Currently', 'O'),
#  ('working', 'O'),
#  ('on', 'O'),
#  ('Chat', 'O'),
#  ('-', 'O'),
#  ('bot', 'O'),
#  ('.', 'O'),
#  ('Developing', 'O'),
#  ('Backend', 'O'),
#  ('Oracle', 'O'),
#  ('PeopleSoft', 'O'),
#  ('Queries', 'O'),
#  ('for', 'O'),
#  ('the', 'O'),
#  ('Bot', 'O'),
#  ('which', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('triggered', 'O'),
#  ('based', 'O'),
#  ('on', 'O'),
#  ('given', 'O'),
#  ('input', 'O'),
#  ('.', 'O'),
#  ('Also', 'O'),
#  (',', 'O'),
#  ('Training', 'O'),
#  ('the', 'O'),
#  ('bot', 'O'),
#  ('for', 'O'),
#  ('different', 'O'),
#  ('possible', 'O'),
#  ('utterances', 'O'),
#  ('(', 'O'),
#  ('Both', 'O'),
#  ('positive', 'O'),
#  ('and', 'O'),
#  ('negative', 'O'),
#  (')', 'O'),
#  (',', 'O'),
#  ('which', 'O'),
#  ('will', 'O'),
#  ('be', 'O'),
#  ('given', 'O'),
#  ('as', 'O'),
#  ('input', 'O'),
#  ('by', 'O'),
#  ('the', 'O'),
#  ('user', 'O'),
#  ('.', 'O'),
#  (' ', 'O'),
#  ('EDUCATION', 'O'),
#  (' ', 'O'),
#  ('B.E', 'B-Designation'),
#  ('in', 'I-Designation'),
#  ('Information', 'I-Designation'),
#  ('science', 'I-Designation'),
#  ('and', 'I-Designation'),
#  ('engineering', 'L-Designation'),
#  (' ', 'O'),
#  ('B.v.b', 'B-College Name'),
#  ('college', 'I-College Name'),
#  ('of', 'I-College Name'),
#  ('engineering', 'I-College Name'),
#  ('and', 'I-College Name'),
#  ('technology', 'L-College Name'),
#  ('-', 'O'),
#  (' ', 'O'),
#  ('Hubli', 'O'),
#  (',', 'O'),
#  ('Karnataka', 'O'),
#  (' ', 'O'),
#  ('August', 'O'),
#  ('2013', 'O'),
#  ('to', 'O'),
#  ('June', 'O'),
#  ('2017', 'U-Graduation Year'),
#  (' ', 'O'),
#  ('12th', 'O'),
#  ('in', 'O'),
#  ('Mathematics', 'O'),
#  (' ', 'O'),
#  ('Woodbine', 'B-College Name'),
#  ('modern', 'I-College Name'),
#  ('school', 'L-College Name'),
#  (' ', 'O'),
#  ('April', 'O'),
#  ('2011', 'O'),
#  ('to', 'O'),
#  ('March', 'O'),
#  ('2013', 'O'),
#  (' ', 'O'),
#  ('10th', 'O'),
#  (' ', 'O'),
#  ('Kendriya', 'B-College Name'),
#  ('Vidyalaya', 'L-College Name'),
#  (' ', 'O'),
#  ('April', 'O'),
#  ('2001', 'O'),
#  ('to', 'O'),
#  ('March', 'O'),
#  ('2011', 'O'),
#  (' ', 'O'),
#  ('SKILLS', 'O'),
#  (' ', 'O'),
#  ('C', 'B-Skills'),
#  ('(', 'O'),
#  ('Less', 'I-Skills'),
#  ('than', 'I-Skills'),
#  ('1', 'I-Skills'),
#  ('year', 'I-Skills'),
#  (')', 'O'),
#  (',', 'O'),
#  ('Database', 'I-Skills'),
#  ('(', 'O'),
#  ('Less', 'I-Skills'),
#  ('than', 'I-Skills'),
#  ('1', 'I-Skills'),
#  ('year', 'I-Skills'),
#  (')', 'O'),
#  (',', 'O'),
#  ('Database', 'I-Skills'),
#  ('Management', 'I-Skills'),
#  ('(', 'O'),
#  ('Less', 'I-Skills'),
#  ('than', 'I-Skills'),
#  ('1', 'I-Skills'),
#  ('year', 'I-Skills'),
#  (')', 'O'),
#  (',', 'O'),
#  ('Database', 'I-Skills'),
#  ('Management', 'I-Skills'),
#  ('System', 'I-Skills'),
#  ('(', 'O'),
#  ('Less', 'I-Skills'),
#  ('than', 'I-Skills'),
#  ('1', 'I-Skills'),
#  ('year', 'I-Skills'),
#  (')', 'O'),
#  (',', 'O'),
#  ('Java', 'I-Skills'),
#  ('(', 'O'),
#  ('Less', 'I-Skills'),
#  ('than', 'I-Skills'),
#  ('1', 'I-Skills'),
#  ('year', 'I-Skills'),
#  (')', 'O'),
#  (' ', 'O'),
#  ('ADDITIONAL', 'O'),
#  ('INFORMATION', 'O'),
#  (' ', 'O'),
#  ('Technical', 'O'),
#  ('Skills', 'O'),
#  (' ', 'O'),
#  ('https://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN',
#   'O'),
#  ('  ', 'O'),
#  ('•', 'O'),
#  ('Programming', 'I-Skills'),
#  ('language', 'I-Skills'),
#  (':', 'O'),
#  ('C', 'I-Skills'),
#  (',', 'O'),
#  ('C++', 'I-Skills'),
#  (',', 'O'),
#  ('Java', 'I-Skills'),
#  ('•', 'O'),
#  ('Oracle', 'I-Skills'),
#  ('PeopleSoft', 'I-Skills'),
#  ('•', 'O'),
#  ('Internet', 'I-Skills'),
#  ('Of', 'I-Skills'),
#  ('Things', 'I-Skills'),
#  ('•', 'O'),
#  ('Machine', 'I-Skills'),
#  ('Learning', 'I-Skills'),
#  ('•', 'O'),
#  ('Database', 'I-Skills'),
#  ('Management', 'I-Skills'),
#  ('System', 'I-Skills'),
#  ('•', 'O'),
#  ('Computer', 'I-Skills'),
#  ('Networks', 'I-Skills'),
#  ('•', 'O'),
#  ('Operating', 'I-Skills'),
#  ('System', 'I-Skills'),
#  ('worked', 'I-Skills'),
#  ('on', 'I-Skills'),
#  (':', 'O'),
#  ('Linux', 'I-Skills'),
#  (',', 'O'),
#  ('Windows', 'I-Skills'),
#  (',', 'O'),
#  ('Mac', 'I-Skills'),
#  (' ', 'O'),
#  ('Non', 'I-Skills'),
#  ('-', 'O'),
#  ('Technical', 'I-Skills'),
#  ('Skills', 'I-Skills'),
#  (' ', 'O'),
#  ('•', 'O'),
#  ('Honest', 'I-Skills'),
#  ('and', 'I-Skills'),
#  ('Hard', 'I-Skills'),
#  ('-', 'O'),
#  ('Working', 'I-Skills'),
#  ('•', 'O'),
#  ('Tolerant', 'I-Skills'),
#  ('and', 'I-Skills'),
#  ('Flexible', 'I-Skills'),
#  ('to', 'I-Skills'),
#  ('Different', 'I-Skills'),
#  ('Situations', 'I-Skills'),
#  ('•', 'O'),
#  ('Polite', 'I-Skills'),
#  ('and', 'I-Skills'),
#  ('Calm', 'I-Skills'),
#  ('•', 'O'),
#  ('Team', 'I-Skills'),
#  ('-', 'O'),
#  ('Player', 'L-Skills')]

# %% [markdown]
# ### From BILOU to SpaCy

# %%
data = [[(doc, annot) for doc, annot in zip(df_data["docs"][i], df_data["annots"][i]) if doc.isalnum() or len(doc) > 1] 
         for i in range(len(df_data))]
data
# Out:
# [[('Abhishek', 'B-Name'),
#   ('Jha', 'L-Name'),
#   ('Application', 'B-Designation'),
#   ('Development', 'I-Designation'),
#   ('Associate', 'L-Designation'),
#   ('Accenture', 'U-Companies worked at'),
#   ('Bengaluru', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('Email', 'O'),
#   ('me', 'O'),
#   ('on', 'O'),
#   ('Indeed', 'B-Email Address'),
#   ('indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a', 'L-Email Address'),
#   ('To', 'O'),
#   ('work', 'O'),
#   ('for', 'O'),
#   ('an', 'O'),
#   ('organization', 'O'),
#   ('which', 'O'),
#   ('provides', 'O'),
#   ('me', 'O'),
#   ('the', 'O'),
#   ('opportunity', 'O'),
#   ('to', 'O'),
#   ('improve', 'O'),
#   ('my', 'O'),
#   ('skills', 'O'),
#   ('and', 'O'),
#   ('knowledge', 'O'),
#   ('for', 'O'),
#   ('my', 'O'),
#   ('individual', 'O'),
#   ('and', 'O'),
#   ('company', 'O'),
#   ("'s", 'O'),
#   ('growth', 'O'),
#   ('in', 'O'),
#   ('best', 'O'),
#   ('possible', 'O'),
#   ('ways', 'O'),
#   ('Willing', 'O'),
#   ('to', 'O'),
#   ('relocate', 'O'),
#   ('to', 'O'),
#   ('Bangalore', 'O'),
#   ('Karnataka', 'O'),
#   ('WORK', 'O'),
#   ('EXPERIENCE', 'O'),
#   ('Application', 'B-Designation'),
#   ('Development', 'I-Designation'),
#   ('Associate', 'L-Designation'),
#   ('Accenture', 'U-Companies worked at'),
#   ('November', 'O'),
#   ('2017', 'O'),
#   ('to', 'O'),
#   ('Present', 'O'),
#   ('Role', 'O'),
#   ('Currently', 'O'),
#   ('working', 'O'),
#   ('on', 'O'),
#   ('Chat', 'O'),
#   ('bot', 'O'),
#   ('Developing', 'O'),
#   ('Backend', 'O'),
#   ('Oracle', 'O'),
#   ('PeopleSoft', 'O'),
#   ('Queries', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('Bot', 'O'),
#   ('which', 'O'),
#   ('will', 'O'),
#   ('be', 'O'),
#   ('triggered', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('given', 'O'),
#   ('input', 'O'),
#   ('Also', 'O'),
#   ('Training', 'O'),
#   ('the', 'O'),
#   ('bot', 'O'),
#   ('for', 'O'),
#   ('different', 'O'),
#   ('possible', 'O'),
#   ('utterances', 'O'),
#   ('Both', 'O'),
#   ('positive', 'O'),
#   ('and', 'O'),
#   ('negative', 'O'),
#   ('which', 'O'),
#   ('will', 'O'),
#   ('be', 'O'),
#   ('given', 'O'),
#   ('as', 'O'),
#   ('input', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('user', 'O'),
#   ('EDUCATION', 'O'),
#   ('B.E', 'B-Designation'),
#   ('in', 'I-Designation'),
#   ('Information', 'I-Designation'),
#   ('science', 'I-Designation'),
#   ('and', 'I-Designation'),
#   ('engineering', 'L-Designation'),
#   ('B.v.b', 'B-College Name'),
#   ('college', 'I-College Name'),
#   ('of', 'I-College Name'),
#   ('engineering', 'I-College Name'),
#   ('and', 'I-College Name'),
#   ('technology', 'L-College Name'),
#   ('Hubli', 'O'),
#   ('Karnataka', 'O'),
#   ('August', 'O'),
#   ('2013', 'O'),
#   ('to', 'O'),
#   ('June', 'O'),
#   ('2017', 'U-Graduation Year'),
#   ('12th', 'O'),
#   ('in', 'O'),
#   ('Mathematics', 'O'),
#   ('Woodbine', 'B-College Name'),
#   ('modern', 'I-College Name'),
#   ('school', 'L-College Name'),
#   ('April', 'O'),
#   ('2011', 'O'),
#   ('to', 'O'),
#   ('March', 'O'),
#   ('2013', 'O'),
#   ('10th', 'O'),
#   ('Kendriya', 'B-College Name'),
#   ('Vidyalaya', 'L-College Name'),
#   ('April', 'O'),
#   ('2001', 'O'),
#   ('to', 'O'),
#   ('March', 'O'),
#   ('2011', 'O'),
#   ('SKILLS', 'O'),
#   ('C', 'B-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('Database', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('Database', 'I-Skills'),
#   ('Management', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('Database', 'I-Skills'),
#   ('Management', 'I-Skills'),
#   ('System', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('Java', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('ADDITIONAL', 'O'),
#   ('INFORMATION', 'O'),
#   ('Technical', 'O'),
#   ('Skills', 'O'),
#   ('https://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('  ', 'O'),
#   ('Programming', 'I-Skills'),
#   ('language', 'I-Skills'),
#   ('C', 'I-Skills'),
#   ('C++', 'I-Skills'),
#   ('Java', 'I-Skills'),
#   ('Oracle', 'I-Skills'),
#   ('PeopleSoft', 'I-Skills'),
#   ('Internet', 'I-Skills'),
#   ('Of', 'I-Skills'),
#   ('Things', 'I-Skills'),
#   ('Machine', 'I-Skills'),
#   ('Learning', 'I-Skills'),
#   ('Database', 'I-Skills'),
#   ('Management', 'I-Skills'),
#   ('System', 'I-Skills'),
#   ('Computer', 'I-Skills'),
#   ('Networks', 'I-Skills'),
#   ('Operating', 'I-Skills'),
#   ('System', 'I-Skills'),
#   ('worked', 'I-Skills'),
#   ('on', 'I-Skills'),
#   ('Linux', 'I-Skills'),
#   ('Windows', 'I-Skills'),
#   ('Mac', 'I-Skills'),
#   ('Non', 'I-Skills'),
#   ('Technical', 'I-Skills'),
#   ('Skills', 'I-Skills'),
#   ('Honest', 'I-Skills'),
#   ('and', 'I-Skills'),
#   ('Hard', 'I-Skills'),
#   ('Working', 'I-Skills'),
#   ('Tolerant', 'I-Skills'),
#   ('and', 'I-Skills'),
#   ('Flexible', 'I-Skills'),
#   ('to', 'I-Skills'),
#   ('Different', 'I-Skills'),
#   ('Situations', 'I-Skills'),
#   ('Polite', 'I-Skills'),
#   ('and', 'I-Skills'),
#   ('Calm', 'I-Skills'),
#   ('Team', 'I-Skills'),
#   ('Player', 'L-Skills')],
#  [('Akhil', 'B-Name'),
#   ('Yadav', 'I-Name'),
#   ('Polemaina', 'L-Name'),
#   ('Hyderabad', 'U-Location'),
#   ('Telangana', 'O'),
#   ('Email', 'O'),
#   ('me', 'O'),
#   ('on', 'O'),
#   ('Indeed', 'O'),
#   ('indeed.com/r/Akhil-Yadav-Polemaina/', 'B-Email Address'),
#   ('f6931801c51c63b1', 'L-Email Address'),
#   ('Senior', 'O'),
#   ('System', 'O'),
#   ('Engineer', 'O'),
#   ('at', 'O'),
#   ('Infosys', 'O'),
#   ('with', 'O'),
#   ('3.2', 'O'),
#   ('years', 'O'),
#   ('of', 'O'),
#   ('experience', 'O'),
#   ('in', 'O'),
#   ('software', 'O'),
#   ('development', 'O'),
#   ('and', 'O'),
#   ('Maintenance', 'O'),
#   ('Maintained', 'O'),
#   ('data', 'O'),
#   ('processing', 'O'),
#   ('using', 'O'),
#   ('mainframe', 'O'),
#   ('technology', 'O'),
#   ('for', 'O'),
#   ('multiple', 'O'),
#   ('front', 'O'),
#   ('end', 'O'),
#   ('applications', 'O'),
#   ('of', 'O'),
#   ('Walmart', 'O'),
#   ('Retail', 'O'),
#   ('Link', 'O'),
#   ('platform', 'O'),
#   ('and', 'O'),
#   ('ensured', 'O'),
#   ('on', 'O'),
#   ('time', 'O'),
#   ('deliverables', 'O'),
#   ('Worked', 'O'),
#   ('on', 'O'),
#   ('automating', 'O'),
#   ('the', 'O'),
#   ('uses', 'O'),
#   ('cases', 'O'),
#   ('to', 'O'),
#   ('reduce', 'O'),
#   ('manual', 'O'),
#   ('effort', 'O'),
#   ('in', 'O'),
#   ('solving', 'O'),
#   ('repeating', 'O'),
#   ('incidents', 'O'),
#   ('using', 'O'),
#   ('Service', 'O'),
#   ('Now', 'O'),
#   ('orchestration', 'O'),
#   ('Possess', 'O'),
#   ('good', 'O'),
#   ('analytical', 'O'),
#   ('logical', 'O'),
#   ('ability', 'O'),
#   ('and', 'O'),
#   ('systematic', 'O'),
#   ('approach', 'O'),
#   ('to', 'O'),
#   ('problem', 'O'),
#   ('analysis', 'O'),
#   ('strong', 'O'),
#   ('debugging', 'O'),
#   ('and', 'O'),
#   ('troubleshooting', 'O'),
#   ('skills', 'O'),
#   ('Good', 'O'),
#   ('exposure', 'O'),
#   ('to', 'O'),
#   ('Retail', 'O'),
#   ('domain', 'O'),
#   ('Willing', 'O'),
#   ('to', 'O'),
#   ('relocate', 'O'),
#   ('to', 'O'),
#   ('hyderbad', 'O'),
#   ('Telangana', 'O'),
#   ('WORK', 'O'),
#   ('EXPERIENCE', 'O'),
#   ('Senior', 'B-Designation'),
#   ('Systems', 'I-Designation'),
#   ('Engineer', 'L-Designation'),
#   ('Infosys', 'B-Companies worked at'),
#   ('Limited', 'L-Companies worked at'),
#   ('Hyderabad', 'U-Location'),
#   ('Telangana', 'O'),
#   ('January', 'O'),
#   ('2015', 'O'),
#   ('to', 'O'),
#   ('Present', 'O'),
#   ('Working', 'O'),
#   ('on', 'O'),
#   ('all', 'O'),
#   ('the', 'O'),
#   ('Major', 'O'),
#   ('and', 'O'),
#   ('Minor', 'O'),
#   ('Enhancement', 'O'),
#   ('requests', 'O'),
#   ('as', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('Maintenance', 'O'),
#   ('and', 'O'),
#   ('Support', 'O'),
#   ('activities', 'O'),
#   ('Identifying', 'O'),
#   ('and', 'O'),
#   ('fixing', 'O'),
#   ('all', 'O'),
#   ('the', 'O'),
#   ('major', 'O'),
#   ('defects', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('applications', 'O'),
#   ('perform', 'O'),
#   ('root', 'O'),
#   ('cause', 'O'),
#   ('analysis', 'O'),
#   ('for', 'O'),
#   ('production', 'O'),
#   ('issues', 'O'),
#   ('Being', 'O'),
#   ('a', 'O'),
#   ('subject', 'O'),
#   ('matter', 'O'),
#   ('expert', 'O'),
#   ('involved', 'O'),
#   ('in', 'O'),
#   ('multiple', 'O'),
#   ('Knowledge', 'O'),
#   ('transfer', 'O'),
#   ('and', 'O'),
#   ('knowledge', 'O'),
#   ('sharing', 'O'),
#   ('sessions', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('client', 'O'),
#   ('Leading', 'O'),
#   ('a', 'O'),
#   ('peer', 'O'),
#   ('group', 'O'),
#   ('and', 'O'),
#   ('taking', 'O'),
#   ('end', 'O'),
#   ('to', 'O'),
#   ('end', 'O'),
#   ('responsibilities', 'O'),
#   ('for', 'O'),
#   ('all', 'O'),
#   ('the', 'O'),
#   ('critical', 'O'),
#   ('issues/', 'O'),
#   ('enhancements', 'O'),
#   ('Identifying', 'O'),
#   ('the', 'O'),
#   ('use', 'O'),
#   ('cases', 'O'),
#   ('which', 'O'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('automated', 'O'),
#   ('using', 'O'),
#   ('Service', 'O'),
#   ('Now', 'O'),
#   ('Orchestration', 'O'),
#   ('Creating', 'O'),
#   ('workflows', 'O'),
#   ('to', 'O'),
#   ('automate', 'O'),
#   ('various', 'O'),
#   ('tasks', 'O'),
#   ('which', 'O'),
#   ('involved', 'O'),
#   ('manual', 'O'),
#   ('intervention', 'O'),
#   ('Direct', 'O'),
#   ('interaction', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('client', 'O'),
#   ('on', 'O'),
#   ('various', 'O'),
#   ('business', 'O'),
#   ('impacting', 'O'),
#   ('issues', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('daily', 'O'),
#   ('basis', 'O'),
#   ('Setting', 'O'),
#   ('up', 'O'),
#   ('Weekly', 'O'),
#   ('Status', 'O'),
#   ('Review', 'O'),
#   ('meetings', 'O'),
#   ('and', 'O'),
#   ('Code', 'O'),
#   ('Review', 'O'),
#   ('meetings', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('client', 'O'),
#   ('Senior', 'B-Designation'),
#   ('Systems', 'I-Designation'),
#   ('Engineer', 'L-Designation'),
#   ('Infosys', 'B-Companies worked at'),
#   ('Limited', 'L-Companies worked at'),
#   ('Hyderabad', 'U-Location'),
#   ('Telangana', 'O'),
#   ('January', 'O'),
#   ('2015', 'O'),
#   ('to', 'O'),
#   ('Present', 'O'),
#   ('Team', 'O'),
#   ('Size', 'O'),
#   ('5', 'O'),
#   ('Project', 'O'),
#   ('Objective', 'O'),
#   ('Providing', 'O'),
#   ('end', 'O'),
#   ('to', 'O'),
#   ('end', 'O'),
#   ('Maintenance', 'O'),
#   ('and', 'O'),
#   ('Support', 'O'),
#   ('activity', 'O'),
#   ('for', 'O'),
#   ('data', 'O'),
#   ('processing', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('most', 'O'),
#   ('critical', 'O'),
#   ('and', 'O'),
#   ('important', 'O'),
#   ('Web', 'O'),
#   ('portal', 'O'),
#   ('Retail', 'O'),
#   ('Link', 'O'),
#   ('along', 'O'),
#   ('with', 'O'),
#   ('over', 'O'),
#   ('40', 'O'),
#   ('applications', 'O'),
#   ('used', 'O'),
#   ('daily', 'O'),
#   ('by', 'O'),
#   ('all', 'O'),
#   ('the', 'O'),
#   ('Suppliers', 'O'),
#   ('and', 'O'),
#   ('Business', 'O'),
#   ('users', 'O'),
#   ('of', 'O'),
#   ('Walmart', 'O'),
#   ('the', 'O'),
#   ('largest', 'O'),
#   ('retailer', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('world', 'O'),
#   ('Retail', 'O'),
#   ('link', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('portal', 'O'),
#   ('which', 'O'),
#   ('hosts', 'O'),
#   ('100', 'O'),
#   ("'s", 'O'),
#   ('of', 'O'),
#   ('applications', 'O'),
#   ('developed', 'O'),
#   ('across', 'O'),
#   ('technologies', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('suppliers', 'O'),
#   ('which', 'O'),
#   ('help', 'O'),
#   ('them', 'O'),
#   ('to', 'O'),
#   ('carry', 'O'),
#   ('on', 'O'),
#   ('day', 'O'),
#   ('to', 'O'),
#   ('day', 'O'),
#   ('activities', 'O'),
#   ('right', 'O'),
#   ('from', 'O'),
#   ('on', 'O'),
#   ('boarding', 'O'),
#   ('to', 'O'),
#   ('tracking', 'O'),
#   ('their', 'O'),
#   ('sales', 'O'),
#   ('This', 'O'),
#   ('involves', 'O'),
#   ('supporting', 'O'),
#   ('https://www.indeed.com/r/Akhil-Yadav-Polemaina/f6931801c51c63b1?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('https://www.indeed.com/r/Akhil-Yadav-Polemaina/f6931801c51c63b1?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('  ', 'O'),
#   ('various', 'O'),
#   ('Decision', 'O'),
#   ('Support', 'O'),
#   ('System', 'O'),
#   ('reports', 'O'),
#   ('which', 'O'),
#   ('helps', 'O'),
#   ('the', 'O'),
#   ('higher', 'O'),
#   ('management', 'O'),
#   ('to', 'O'),
#   ('take', 'O'),
#   ('business', 'O'),
#   ('critical', 'O'),
#   ('decisions', 'O'),
#   ('Responsibilities', 'O'),
#   ('Working', 'O'),
#   ('on', 'O'),
#   ('all', 'O'),
#   ('the', 'O'),
#   ('Major', 'O'),
#   ('and', 'O'),
#   ('Minor', 'O'),
#   ('Enhancement', 'O'),
#   ('requests', 'O'),
#   ('as', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('Maintenance', 'O'),
#   ('and', 'O'),
#   ('Support', 'O'),
#   ('activities', 'O'),
#   ('Identifying', 'O'),
#   ('and', 'O'),
#   ('fixing', 'O'),
#   ('all', 'O'),
#   ('the', 'O'),
#   ('major', 'O'),
#   ('defects', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('applications', 'O'),
#   ('perform', 'O'),
#   ('root', 'O'),
#   ('cause', 'O'),
#   ('analysis', 'O'),
#   ('for', 'O'),
#   ('production', 'O'),
#   ('issues', 'O'),
#   ('Being', 'O'),
#   ('a', 'O'),
#   ('subject', 'O'),
#   ('matter', 'O'),
#   ('expert', 'O'),
#   ('involved', 'O'),
#   ('in', 'O'),
#   ('multiple', 'O'),
#   ('Knowledge', 'O'),
#   ('transfer', 'O'),
#   ('and', 'O'),
#   ('knowledge', 'O'),
#   ('sharing', 'O'),
#   ('sessions', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('client', 'O'),
#   ('Leading', 'O'),
#   ('a', 'O'),
#   ('peer', 'O'),
#   ('group', 'O'),
#   ('and', 'O'),
#   ('taking', 'O'),
#   ('end', 'O'),
#   ('to', 'O'),
#   ('end', 'O'),
#   ('responsibilities', 'O'),
#   ('for', 'O'),
#   ('all', 'O'),
#   ('the', 'O'),
#   ('critical', 'O'),
#   ('issues/', 'O'),
#   ('enhancements', 'O'),
#   ('Identifying', 'O'),
#   ('the', 'O'),
#   ('use', 'O'),
#   ('cases', 'O'),
#   ('which', 'O'),
#   ('can', 'O'),
#   ('be', 'O'),
#   ('automated', 'O'),
#   ('using', 'O'),
#   ('Service', 'O'),
#   ('Now', 'O'),
#   ('Orchestration', 'O'),
#   ('Creating', 'O'),
#   ('workflows', 'O'),
#   ('to', 'O'),
#   ('automate', 'O'),
#   ('various', 'O'),
#   ('tasks', 'O'),
#   ('which', 'O'),
#   ('involved', 'O'),
#   ('manual', 'O'),
#   ('intervention', 'O'),
#   ('Direct', 'O'),
#   ('interaction', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('client', 'O'),
#   ('on', 'O'),
#   ('various', 'O'),
#   ('business', 'O'),
#   ('impacting', 'O'),
#   ('issues', 'O'),
#   ('on', 'O'),
#   ('a', 'O'),
#   ('daily', 'O'),
#   ('basis', 'O'),
#   ('Setting', 'O'),
#   ('up', 'O'),
#   ('Weekly', 'O'),
#   ('Status', 'O'),
#   ('Review', 'O'),
#   ('meetings', 'O'),
#   ('and', 'O'),
#   ('Code', 'O'),
#   ('Review', 'O'),
#   ('meetings', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('client', 'O'),
#   ('EDUCATION', 'O'),
#   ('Electrical', 'B-Degree'),
#   ('and', 'I-Degree'),
#   ('Electronics', 'I-Degree'),
#   ('Engineering', 'L-Degree'),
#   ('Anurag', 'B-College Name'),
#   ('College', 'I-College Name'),
#   ('of', 'I-College Name'),
#   ('Engineering', 'I-College Name'),
#   ('Jntuh', 'I-College Name'),
#   ('SKILLS', 'O'),
#   ('servicenow', 'U-Skills'),
#   ('1', 'O'),
#   ('year', 'O'),
#   ('Mainframe', 'U-Skills'),
#   ('3', 'O'),
#   ('years', 'O'),
#   ('cobol', 'U-Skills'),
#   ('3', 'O'),
#   ('years', 'O'),
#   ('Jcl', 'U-Skills'),
#   ('3', 'O'),
#   ('years', 'O'),
#   ('Teradata', 'U-Skills'),
#   ('3', 'O'),
#   ('years', 'O'),
#   ('ADDITIONAL', 'O'),
#   ('INFORMATION', 'O'),
#   ('Technical', 'O'),
#   ('Skills', 'O'),
#   ('Domain', 'O'),
#   ('Retail', 'O'),
#   ('Technology', 'O'),
#   ('Mainframe', 'U-Skills'),
#   ('COBOL', 'O'),
#   ('JCL', 'O'),
#   ('DB2', 'O'),
#   ('Teradata', 'U-Skills'),
#   ('Service', 'O'),
#   ('now', 'O'),
#   ('Operating', 'O'),
#   ('System', 'O'),
#   ('Mainframe', 'U-Skills'),
#   ('z', 'O'),
#   ('OS', 'O'),
#   ('Database', 'O'),
#   ('DB2', 'O'),
#   ('SQL', 'O'),
#   ('Teradata', 'U-Skills'),
#   ('Utilities', 'O'),
#   ('FILE', 'O'),
#   ('AID', 'O'),
#   ('IDCAMS', 'O'),
#   ('DFSORT', 'O'),
#   ('basics', 'O'),
#   ('LIBRARIAN', 'O'),
#   ('FTP', 'O'),
#   ('SFTP', 'O'),
#   ('CA-7', 'O'),
#   ('basics', 'O'),
#   ('Tools', 'O'),
#   ('Query', 'O'),
#   ('Management', 'O'),
#   ('Tool', 'O'),
#   ('QMF', 'O'),
#   ('SQL', 'O'),
#   ('Assistant', 'O'),
#   ('Service', 'O'),
#   ('now', 'O'),
#   ('Remedy', 'O'),
#   ('Key', 'O'),
#   ('Strengths', 'O'),
#   ('Effective', 'O'),
#   ('Communication', 'O'),
#   ('Skills', 'O'),
#   ('and', 'O'),
#   ('Zeal', 'O'),
#   ('to', 'O'),
#   ('learn', 'O'),
#   ('Flexibility', 'O'),
#   ('and', 'O'),
#   ('Adaptability', 'O'),
#   ('Good', 'O'),
#   ('Leadership', 'O'),
#   ('Qualities', 'O'),
#   ('Analytical', 'O'),
#   ('and', 'O'),
#   ('Problem', 'O'),
#   ('Solving', 'O'),
#   ('Skills', 'O'),
#   ('Achievements', 'O'),
#   ('Received', 'O'),
#   ('STAR', 'O'),
#   ('award', 'O'),
#   ('for', 'O'),
#   ('working', 'O'),
#   ('on', 'O'),
#   ('various', 'O'),
#   ('system', 'O'),
#   ('improvement', 'O'),
#   ('and', 'O'),
#   ('automation', 'O'),
#   ('activities', 'O'),
#   ('Received', 'O'),
#   ('multiple', 'O'),
#   ('INSTA', 'O'),
#   ('awards', 'O'),
#   ('for', 'O'),
#   ('my', 'O'),
#   ('performance', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('projects', 'O'),
#   ('worked', 'O')],
#  [('Arun', 'B-Name'),
#   ('Elumalai', 'L-Name'),
#   ('QA', 'B-Designation'),
#   ('Tester', 'L-Designation'),
#   ('Chennai', 'U-Location'),
#   ('Tamil', 'O'),
#   ('Nadu', 'O'),
#   ('Email', 'O'),
#   ('me', 'O'),
#   ('on', 'O'),
#   ('Indeed', 'O'),
#   ('indeed.com/r/Arun-Elumalai/26575d617d50ea04', 'O'),
#   ('15', 'B-Years of Experience'),
#   ('Months', 'L-Years of Experience'),
#   ('of', 'O'),
#   ('Experience', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('QA', 'O'),
#   ('Tester', 'O'),
#   ('in', 'O'),
#   ('Software', 'O'),
#   ('Testing', 'O'),
#   ('Mainframe', 'O'),
#   ('Experience', 'O'),
#   ('in', 'O'),
#   ('Automation', 'O'),
#   ('Functional', 'O'),
#   ('UI', 'O'),
#   ('testing', 'O'),
#   ('and', 'O'),
#   ('Regression', 'O'),
#   ('Testing', 'O'),
#   ('Involvement', 'O'),
#   ('in', 'O'),
#   ('preparation', 'O'),
#   ('of', 'O'),
#   ('Test', 'O'),
#   ('scenarios', 'O'),
#   ('Test', 'O'),
#   ('cases', 'O'),
#   ('and', 'O'),
#   ('executing', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('Defect', 'O'),
#   ('reporting', 'O'),
#   ('and', 'O'),
#   ('tracking', 'O'),
#   ('via', 'O'),
#   ('Rational', 'O'),
#   ('Quality', 'O'),
#   ('Manager', 'O'),
#   ('Preparation', 'O'),
#   ('of', 'O'),
#   ('test', 'O'),
#   ('closure', 'O'),
#   ('reports', 'O'),
#   ('WORK', 'O'),
#   ('EXPERIENCE', 'O'),
#   ('QA', 'B-Designation'),
#   ('Tester', 'L-Designation'),
#   ('Accenture', 'U-Companies worked at'),
#   ('November', 'O'),
#   ('2016', 'O'),
#   ('to', 'O'),
#   ('March', 'O'),
#   ('2018', 'O'),
#   ('Associate', 'O'),
#   ('Software', 'O'),
#   ('Engineer', 'O'),
#   ('Accenture', 'O'),
#   ('Services', 'O'),
#   ('Pvt', 'O'),
#   ('Ltd', 'O'),
#   ('Nov', 'O'),
#   ('2016', 'O'),
#   ('to', 'O'),
#   ('Mar', 'O'),
#   ('2018', 'O'),
#   ('Domain', 'O'),
#   ('Financial', 'O'),
#   ('Services', 'O'),
#   ('Payments', 'O'),
#   ('Domain', 'O'),
#   ('Application', 'O'),
#   ('VisionPLUS', 'O'),
#   ('PROJECT', 'O'),
#   ('PROFILE', 'O'),
#   ('Client', 'O'),
#   ('First', 'O'),
#   ('Data', 'O'),
#   ('Corporation', 'O'),
#   ('Role', 'O'),
#   ('QA', 'B-Designation'),
#   ('Tester', 'L-Designation'),
#   ('Application', 'O'),
#   ('VisionPLUS', 'O'),
#   ('Description', 'O'),
#   ('and', 'O'),
#   ('Responsibilities', 'O'),
#   ('1', 'O'),
#   ('Have', 'O'),
#   ('worked', 'O'),
#   ('in', 'O'),
#   ('functional', 'O'),
#   ('releases', 'O'),
#   ('and', 'O'),
#   ('tested', 'O'),
#   ('across', 'O'),
#   ('clients', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('EMEA', 'O'),
#   ('region', 'O'),
#   ('Performed', 'O'),
#   ('system', 'O'),
#   ('integration', 'O'),
#   ('testing', 'O'),
#   ('for', 'O'),
#   ('new', 'O'),
#   ('clients', 'O'),
#   ('that', 'O'),
#   ('came', 'O'),
#   ('into', 'O'),
#   ('VisionPlus', 'O'),
#   ('2', 'O'),
#   ('Automated', 'O'),
#   ('manual', 'O'),
#   ('scripts', 'O'),
#   ('in', 'O'),
#   ('Regression', 'O'),
#   ('Testing', 'O'),
#   ('and', 'O'),
#   ('Executing', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('using', 'O'),
#   ('Selenium', 'O'),
#   ('Web', 'O'),
#   ('driver', 'O'),
#   ('through', 'O'),
#   ('Sauce', 'O'),
#   ('Labs', 'O'),
#   ('3', 'O'),
#   ('Performed', 'O'),
#   ('UI', 'O'),
#   ('Testing', 'O'),
#   ('in', 'O'),
#   ('First', 'O'),
#   ('Apply', 'O'),
#   ('and', 'O'),
#   ('First', 'O'),
#   ('Online', 'O'),
#   ('4', 'O'),
#   ('Tested', 'O'),
#   ('various', 'O'),
#   ('functionalities', 'O'),
#   ('of', 'O'),
#   ('credit', 'O'),
#   ('card', 'O'),
#   ('life', 'O'),
#   ('cycle', 'O'),
#   ('like', 'O'),
#   ('account', 'O'),
#   ('boarding', 'O'),
#   ('embossing', 'O'),
#   ('account', 'O'),
#   ('card', 'O'),
#   ('transfer', 'O'),
#   ('replacement', 'O'),
#   ('and', 'O'),
#   ('reissue', 'O'),
#   ('of', 'O'),
#   ('cards', 'O'),
#   ('5', 'O'),
#   ('Tested', 'O'),
#   ('manual', 'O'),
#   ('and', 'O'),
#   ('auto', 'O'),
#   ('enrollment', 'O'),
#   ('of', 'O'),
#   ('offers', 'O'),
#   ('cashback', 'O'),
#   ('offers', 'O'),
#   ('PERFORMANCE', 'O'),
#   ('ACHIEVEMENTS', 'O'),
#   ('Won', 'O'),
#   ('The', 'O'),
#   ('Rising', 'O'),
#   ('Star', 'O'),
#   ('Award', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('year', 'O'),
#   ('2017', 'O'),
#   ('EDUCATION', 'O'),
#   ('Bachelor', 'B-Degree'),
#   ('of', 'I-Degree'),
#   ('Engineering', 'I-Degree'),
#   ('in', 'I-Degree'),
#   ('Automobile', 'I-Degree'),
#   ('Engineering', 'L-Degree'),
#   ('https://www.indeed.com/r/Arun-Elumalai/26575d617d50ea04?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('  ', 'O'),
#   ('Sri', 'B-College Name'),
#   ('Venkateswara', 'I-College Name'),
#   ('College', 'I-College Name'),
#   ('Of', 'I-College Name'),
#   ('Engineering', 'L-College Name'),
#   ('Chennai', 'U-Location'),
#   ('Tamil', 'O'),
#   ('Nadu', 'O'),
#   ('2012', 'O'),
#   ('to', 'O'),
#   ('2016', 'O'),
#   ('SKILLS', 'O'),
#   ('ANSYS', 'B-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('CATIA', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('CREO', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('PARAMETRIC', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('PYTHON', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('Selenium', 'I-Skills'),
#   ('Selenium', 'I-Skills'),
#   ('Webdriver', 'I-Skills'),
#   ('Testing', 'I-Skills'),
#   ('Functional', 'I-Skills'),
#   ('Testing', 'I-Skills'),
#   ('Automation', 'I-Skills'),
#   ('Testing', 'I-Skills'),
#   ('Regression', 'I-Skills'),
#   ('Testing', 'I-Skills'),
#   ('Quality', 'I-Skills'),
#   ('Assurance', 'L-Skills'),
#   ('ADDITIONAL', 'O'),
#   ('INFORMATION', 'O'),
#   ('TECHNICAL', 'O'),
#   ('SKILLS', 'O'),
#   ('Languages', 'I-Skills'),
#   ('Python', 'I-Skills'),
#   ('Software', 'I-Skills'),
#   ('Tools', 'I-Skills'),
#   ('Selenium', 'I-Skills'),
#   ('WAF', 'I-Skills'),
#   ('Sauce', 'I-Skills'),
#   ('Labs', 'I-Skills'),
#   ('Jenkins', 'I-Skills'),
#   ('Creo', 'I-Skills'),
#   ('parametric', 'I-Skills'),
#   ('2.0', 'I-Skills'),
#   ('Catia', 'I-Skills'),
#   ('V6', 'I-Skills'),
#   ('Ansys', 'L-Skills')],
#  [('Ashalata', 'O'),
#   ('Bisoyi', 'O'),
#   ('Transaction', 'O'),
#   ('Processor', 'O'),
#   ('Oracle', 'O'),
#   ('India', 'O'),
#   ('Private', 'O'),
#   ('Limited', 'O'),
#   ('Bengaluru', 'O'),
#   ('Karnataka', 'O'),
#   ('Email', 'O'),
#   ('me', 'O'),
#   ('on', 'O'),
#   ('Indeed', 'O'),
#   ('indeed.com/r/Ashalata-Bisoyi/cf02125911cfb5df', 'O'),
#   ('To', 'O'),
#   ('secure', 'O'),
#   ('a', 'O'),
#   ('position', 'O'),
#   ('an', 'O'),
#   ('esteem', 'O'),
#   ('organization', 'O'),
#   ('with', 'O'),
#   ('good', 'O'),
#   ('working', 'O'),
#   ('culture', 'O'),
#   ('that', 'O'),
#   ('will', 'O'),
#   ('help', 'O'),
#   ('my', 'O'),
#   ('career', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('field', 'O'),
#   ('of', 'O'),
#   ('finance', 'O'),
#   ('through', 'O'),
#   ('my', 'O'),
#   ('sincerity', 'O'),
#   ('hard', 'O'),
#   ('works', 'O'),
#   ('and', 'O'),
#   ('skills', 'O'),
#   ('WORK', 'O'),
#   ('EXPERIENCE', 'O'),
#   ('Transaction', 'O'),
#   ('Processor', 'O'),
#   ('Oracle', 'O'),
#   ('India', 'O'),
#   ('Private', 'O'),
#   ('Limited', 'O'),
#   ('April', 'O'),
#   ('2016', 'O'),
#   ('to', 'O'),
#   ('Present', 'O'),
#   ('2', 'O'),
#   ('Year', 'O'),
#   ('of', 'O'),
#   ('experience', 'O'),
#   ('with', 'O'),
#   ('Oracle', 'O'),
#   ('India', 'O'),
#   ('Private', 'O'),
#   ('Limited', 'O'),
#   ('in', 'O'),
#   ('expense', 'O'),
#   ('team', 'O'),
#   ('My', 'O'),
#   ('work', 'O'),
#   ('is', 'O'),
#   ('auditing', 'O'),
#   ('of', 'O'),
#   ('expense', 'O'),
#   ('reports', 'O'),
#   ('of', 'O'),
#   ('employees', 'O'),
#   ('of', 'O'),
#   ('all', 'O'),
#   ('the', 'O'),
#   ('countries', 'O'),
#   ('handling', 'O'),
#   ('queries', 'O'),
#   ('through', 'O'),
#   ('emails', 'O'),
#   ('and', 'O'),
#   ('calls', 'O'),
#   ('also', 'O'),
#   ('JOB', 'O'),
#   ('DESCRIPTION', 'O'),
#   ('Auditing', 'O'),
#   ('of', 'O'),
#   ('expense', 'O'),
#   ('reports', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('employees', 'O'),
#   ('for', 'O'),
#   ('all', 'O'),
#   ('the', 'O'),
#   ('countries', 'O'),
#   ('and', 'O'),
#   ('working', 'O'),
#   ('on', 'O'),
#   ('service', 'O'),
#   ('portal', 'O'),
#   ('Answering', 'O'),
#   ('queries', 'O'),
#   ('through', 'O'),
#   ('email', 'O'),
#   ('Handling', 'O'),
#   ('the', 'O'),
#   ('team', 'O'),
#   ('in', 'O'),
#   ('absence', 'O'),
#   ('of', 'O'),
#   ('seniors', 'O'),
#   ('Working', 'O'),
#   ('on', 'O'),
#   ('Payment', 'O'),
#   ('Rejections', 'O'),
#   ('export', 'O'),
#   ('of', 'O'),
#   ('expense', 'O'),
#   ('reports', 'O'),
#   ('to', 'O'),
#   ('AP', 'O'),
#   ('Take', 'O'),
#   ('care', 'O'),
#   ('of', 'O'),
#   ('running', 'O'),
#   ('Backlog', 'O'),
#   ('Having', 'O'),
#   ('knowledge', 'O'),
#   ('about', 'O'),
#   ('travel', 'O'),
#   ('advance', 'O'),
#   ('EDUCATION', 'O'),
#   ('Master', 'B-Degree'),
#   ('of', 'I-Degree'),
#   ('Finance', 'I-Degree'),
#   ('and', 'I-Degree'),
#   ('Control', 'I-Degree'),
#   ('in', 'I-Degree'),
#   ('MFC', 'L-Degree'),
#   ('Khallikote', 'B-College Name'),
#   ('Autonomous', 'I-College Name'),
#   ('college', 'L-College Name'),
#   ('Brahmapur', 'O'),
#   ('Orissa', 'O'),
#   ('2015', 'U-Graduation Year'),
#   ('Bachelor', 'B-Degree'),
#   ('in', 'I-Degree'),
#   ('Commerce', 'L-Degree'),
#   ('Berhampur', 'B-College Name'),
#   ('university', 'L-College Name'),
#   ('Brahmapur', 'O'),
#   ('Orissa', 'O'),
#   ('2013', 'U-Graduation Year'),
#   ('Accounting', 'U-Degree'),
#   ('Science', 'B-College Name'),
#   ('College', 'I-College Name'),
#   ('Hinjilicut', 'L-College Name'),
#   ('Brahmapur', 'O'),
#   ('Orissa', 'O'),
#   ('2010', 'U-Graduation Year'),
#   ('Education', 'O'),
#   ('Council', 'O'),
#   ('of', 'O'),
#   ('Higher', 'O'),
#   ('Secondary', 'O'),
#   ('Orissa', 'O'),
#   ('IN', 'O'),
#   ('2008', 'U-Graduation Year'),
#   ('Government', 'B-College Name'),
#   ('girls', 'I-College Name'),
#   ('High', 'I-College Name'),
#   ('school', 'L-College Name'),
#   ('Hinjilikatu', 'O'),
#   ('Orissa', 'O'),
#   ('https://www.indeed.com/r/Ashalata-Bisoyi/cf02125911cfb5df?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('  ', 'O'),
#   ('Board', 'B-Degree'),
#   ('of', 'I-Degree'),
#   ('Secondary', 'I-Degree'),
#   ('Education', 'L-Degree'),
#   ('Orissa', 'O'),
#   ('IN', 'O'),
#   ('ADDITIONAL', 'O'),
#   ('INFORMATION', 'O'),
#   ('Good', 'O'),
#   ('analytical', 'O'),
#   ('skills', 'O'),
#   ('and', 'O'),
#   ('flexible', 'O'),
#   ('in', 'O'),
#   ('work', 'O'),
#   ('atmosphere', 'O'),
#   ('Able', 'O'),
#   ('to', 'O'),
#   ('handle', 'O'),
#   ('complex', 'O'),
#   ('situation', 'O'),
#   ('under', 'O'),
#   ('process', 'O'),
#   ('Willingness', 'O'),
#   ('to', 'O'),
#   ('learn', 'O'),
#   ('Ability', 'O'),
#   ('to', 'O'),
#   ('meet', 'O'),
#   ('deadlines', 'O'),
#   ('Every', 'O'),
#   ('time', 'O'),
#   ('accept', 'O'),
#   ('the', 'O'),
#   ('new', 'O'),
#   ('challenges', 'O'),
#   ('OTHER', 'O'),
#   ('QUALIFICATIONS', 'O'),
#   ('DOEACC', 'B-Skills'),
#   ('O', 'I-Skills'),
#   ('LEVEL', 'L-Skills'),
#   ('M.S.', 'B-Skills'),
#   ('OFFICE', 'L-Skills')],
#  [('Asish', 'B-Name'),
#   ('Ratha', 'L-Name'),
#   ('Subject', 'B-Designation'),
#   ('matter', 'I-Designation'),
#   ('Expert', 'L-Designation'),
#   ('Accenture', 'U-Companies worked at'),
#   ('Chennai', 'U-Location'),
#   ('Tamil', 'O'),
#   ('Nadu', 'O'),
#   ('Email', 'O'),
#   ('me', 'O'),
#   ('on', 'O'),
#   ('Indeed', 'O'),
#   ('indeed.com/r/Asish-Ratha/853988e0e0e236a3', 'U-Location'),
#   ('WORK', 'O'),
#   ('EXPERIENCE', 'O'),
#   ('Subject', 'B-Designation'),
#   ('matter', 'I-Designation'),
#   ('Expert', 'L-Designation'),
#   ('Accenture', 'U-Companies worked at'),
#   ('March', 'O'),
#   ('2012', 'O'),
#   ('to', 'O'),
#   ('Present', 'O'),
#   ('Subject', 'O'),
#   ('matter', 'O'),
#   ('expert', 'O'),
#   ('EDUCATION', 'O'),
#   ('Berhampur', 'B-College Name'),
#   ('university', 'L-College Name'),
#   ('Khallikote', 'B-College Name'),
#   ('autonomous', 'I-College Name'),
#   ('college', 'L-College Name'),
#   ('Brahmapur', 'O'),
#   ('Orissa', 'O'),
#   ('SKILLS', 'O'),
#   ('Invoice', 'B-Skills'),
#   ('5', 'I-Skills'),
#   ('years', 'I-Skills'),
#   ('posting', 'I-Skills'),
#   ('5', 'I-Skills'),
#   ('years', 'I-Skills'),
#   ('TRAINING', 'I-Skills'),
#   ('4', 'I-Skills'),
#   ('years', 'I-Skills'),
#   ('ADDITIONAL', 'I-Skills'),
#   ('INFORMATION', 'I-Skills'),
#   ('SKILLS', 'I-Skills'),
#   ('Invoice', 'I-Skills'),
#   ('processing', 'I-Skills'),
#   ('Team', 'I-Skills'),
#   ('handling', 'I-Skills'),
#   ('new', 'I-Skills'),
#   ('joiners', 'I-Skills'),
#   ('training.sap', 'I-Skills'),
#   ('posting', 'I-Skills'),
#   ('vendor', 'I-Skills'),
#   ('call', 'I-Skills'),
#   ('attend', 'I-Skills'),
#   ('and', 'I-Skills'),
#   ('resolve', 'I-Skills'),
#   ('the', 'I-Skills'),
#   ('issue', 'I-Skills'),
#   ('meet', 'I-Skills'),
#   ('SLA', 'I-Skills'),
#   ('tat', 'I-Skills'),
#   ('working', 'I-Skills'),
#   ('with', 'I-Skills'),
#   ('client', 'I-Skills'),
#   ('tool', 'I-Skills'),
#   ('https://www.indeed.com/r/Asish-Ratha/853988e0e0e236a3?isid=rex-download&ikw=download-top&co=IN',
#    'O')],
#  [('Avin', 'B-Name'),
#   ('Sharma', 'L-Name'),
#   ('Senior', 'B-Designation'),
#   ('Associate', 'I-Designation'),
#   ('Consultant', 'L-Designation'),
#   ('Infosys', 'B-Companies worked at'),
#   ('Limited', 'L-Companies worked at'),
#   ('Hyderabad', 'U-Location'),
#   ('Telangana', 'O'),
#   ('Email', 'O'),
#   ('me', 'O'),
#   ('on', 'O'),
#   ('Indeed', 'O'),
#   ('indeed.com/r/Avin-Sharma/3ad8a8b57a172613', 'U-Email Address'),
#   ('WORK', 'O'),
#   ('EXPERIENCE', 'O'),
#   ('Senior', 'O'),
#   ('Associate', 'O'),
#   ('Consultant', 'O'),
#   ('Infosys', 'B-Companies worked at'),
#   ('Limited', 'L-Companies worked at'),
#   ('July', 'O'),
#   ('2015', 'U-Graduation Year'),
#   ('to', 'O'),
#   ('Present', 'O'),
#   ('Worked', 'O'),
#   ('on', 'O'),
#   ('Presales', 'O'),
#   ('activities', 'O'),
#   ('preparing', 'O'),
#   ('Proposals', 'O'),
#   ('RFP', 'O'),
#   ("'s", 'O'),
#   ('preparing', 'O'),
#   ('presentations', 'O'),
#   ('budgets/', 'O'),
#   ('quotations', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('client', 'O'),
#   ('requirements', 'O'),
#   ('Responsible', 'O'),
#   ('for', 'O'),
#   ('entire', 'O'),
#   ('sales', 'O'),
#   ('cycle', 'O'),
#   ('from', 'O'),
#   ('market', 'O'),
#   ('research', 'O'),
#   ('for', 'O'),
#   ('prospective', 'O'),
#   ('clients', 'O'),
#   ('to', 'O'),
#   ('final', 'O'),
#   ('negotiation', 'O'),
#   ('sales', 'O'),
#   ('closure', 'O'),
#   ('Worked', 'O'),
#   ('on', 'O'),
#   ('mapping', 'O'),
#   ('commercials', 'O'),
#   ('to', 'O'),
#   ('increase', 'O'),
#   ('the', 'O'),
#   ('profits', 'O'),
#   ('and', 'O'),
#   ('resources', 'O'),
#   ('planning/', 'O'),
#   ('utilization', 'O'),
#   ('Leading', 'O'),
#   ('and', 'O'),
#   ('coordinating', 'O'),
#   ('a', 'O'),
#   ('team', 'O'),
#   ('of', 'O'),
#   ('business', 'O'),
#   ('analysts', 'O'),
#   ('developers', 'O'),
#   ('and', 'O'),
#   ('testers', 'O'),
#   ('for', 'O'),
#   ('execution', 'O'),
#   ('of', 'O'),
#   ('multiple', 'O'),
#   ('projects', 'O'),
#   ('Developed', 'O'),
#   ('strategies', 'O'),
#   ('and', 'O'),
#   ('generated', 'O'),
#   ('business', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('firm', 'O'),
#   ('by', 'O'),
#   ('building', 'O'),
#   ('corporate', 'O'),
#   ('relationships', 'O'),
#   ('with', 'O'),
#   ('client', 'O'),
#   ('Senior', 'O'),
#   ('System', 'O'),
#   ('Engineer', 'O'),
#   ('Infosys', 'B-Companies worked at'),
#   ('Limited', 'L-Companies worked at'),
#   ('August', 'O'),
#   ('2008', 'O'),
#   ('to', 'O'),
#   ('April', 'O'),
#   ('2013', 'O'),
#   ('Worked', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('quality', 'O'),
#   ('analyst', 'O'),
#   ('for', 'O'),
#   ('client', 'O'),
#   ('performed', 'O'),
#   ('system', 'O'),
#   ('testing', 'O'),
#   ('for', 'O'),
#   ('their', 'O'),
#   ('customer', 'O'),
#   ('web', 'O'),
#   ('portal', 'O'),
#   ('having', 'O'),
#   ('modules', 'O'),
#   ('like', 'O'),
#   ('Dashboard', 'O'),
#   ('Billing', 'O'),
#   ('Shop', 'O'),
#   ('Payments', 'O'),
#   ('Login', 'O'),
#   ('etc', 'O'),
#   ('Led', 'O'),
#   ('a', 'O'),
#   ('team', 'O'),
#   ('of', 'O'),
#   ('three', 'O'),
#   ('system', 'O'),
#   ('engineers', 'O'),
#   ('identified', 'O'),
#   ('competency', 'O'),
#   ('gap', 'O'),
#   ('and', 'O'),
#   ('conducted', 'O'),
#   ('knowledge', 'O'),
#   ('sharing', 'O'),
#   ('sessions', 'O'),
#   ('for', 'O'),
#   ('new', 'O'),
#   ('team', 'O'),
#   ('members', 'O'),
#   ('Communicated', 'O'),
#   ('with', 'O'),
#   ('the', 'O'),
#   ('client', 'O'),
#   ('team', 'O'),
#   ('members', 'O'),
#   ('on', 'O'),
#   ('frequent', 'O'),
#   ('basis', 'O'),
#   ('for', 'O'),
#   ('understanding', 'O'),
#   ('their', 'O'),
#   ('issues', 'O'),
#   ('and', 'O'),
#   ('bringing', 'O'),
#   ('action', 'O'),
#   ('items', 'O'),
#   ('to', 'O'),
#   ('closure', 'O'),
#   ('Independently', 'O'),
#   ('handled', 'O'),
#   ('the', 'O'),
#   ('responsibility', 'O'),
#   ('for', 'O'),
#   ('designing', 'O'),
#   ('manual', 'O'),
#   ('test', 'O'),
#   ('cases', 'O'),
#   ('and', 'O'),
#   ('executing', 'O'),
#   ('them', 'O'),
#   ('Worked', 'O'),
#   ('on', 'O'),
#   ('client', 'O'),
#   ("'s", 'O'),
#   ('merger', 'O'),
#   ('Integration', 'O'),
#   ('application', 'O'),
#   ('as', 'O'),
#   ('a', 'O'),
#   ('Developer', 'O'),
#   ('which', 'O'),
#   ('involved', 'O'),
#   ('migration', 'O'),
#   ('from', 'O'),
#   ('lower', 'O'),
#   ('framework', 'O'),
#   ('to', 'O'),
#   ('higher', 'O'),
#   ('framework', 'O'),
#   ('Responsible', 'O'),
#   ('for', 'O'),
#   ('migrating', 'O'),
#   ('the', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('application', 'O'),
#   ('developed', 'O'),
#   ('in', 'O'),
#   ('dot', 'O'),
#   ('net', 'O'),
#   ('from', 'O'),
#   ('lower', 'O'),
#   ('version', 'O'),
#   ('to', 'O'),
#   ('higher', 'O'),
#   ('version', 'O'),
#   ('Developed', 'O'),
#   ('the', 'O'),
#   ('internal', 'O'),
#   ('portals', 'O'),
#   ('on', 'O'),
#   ('Dot', 'O'),
#   ('Net', 'O'),
#   ('platform', 'O'),
#   ('for', 'O'),
#   ('Infosys', 'O'),
#   ('team', 'O'),
#   ('members', 'O'),
#   ('Completed', 'O'),
#   ('the', 'O'),
#   ('assigned', 'O'),
#   ('tasks', 'O'),
#   ('as', 'O'),
#   ('per', 'O'),
#   ('the', 'O'),
#   ('timelines', 'O'),
#   ('and', 'O'),
#   ('ensured', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('given', 'O'),
#   ('tasks', 'O'),
#   ('are', 'O'),
#   ('completed', 'O'),
#   ('with', 'O'),
#   ('compliance', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('benchmarks', 'O'),
#   ('https://www.indeed.com/r/Avin-Sharma/3ad8a8b57a172613?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('  ', 'O'),
#   ('Received', 'O'),
#   ('STAR', 'O'),
#   ('Certification', 'O'),
#   ('for', 'O'),
#   ('showcasing', 'O'),
#   ('outstanding', 'O'),
#   ('Soft', 'O'),
#   ('Skills', 'O'),
#   ('on', 'O'),
#   ('Business', 'O'),
#   ('interpersonal', 'O'),
#   ('communication', 'O'),
#   ('for', 'O'),
#   ('Client', 'O'),
#   ('delight', 'O'),
#   ('Guru', 'O'),
#   ('Nanak', 'O'),
#   ('Dev', 'O'),
#   ('University', 'O'),
#   ('Amritsar', 'O'),
#   ('Punjab', 'O'),
#   ('July', 'O'),
#   ('2004', 'O'),
#   ('to', 'O'),
#   ('June', 'O'),
#   ('2008', 'O'),
#   ('EDUCATION', 'O'),
#   ('Great', 'B-College Name'),
#   ('Lakes', 'I-College Name'),
#   ('Institute', 'I-College Name'),
#   ('of', 'I-College Name'),
#   ('Management', 'L-College Name'),
#   ('Chennai', 'O'),
#   ('Tamil', 'O'),
#   ('Nadu', 'O'),
#   ('April', 'O'),
#   ('2014', 'O'),
#   ('to', 'O'),
#   ('April', 'O'),
#   ('2015', 'U-Graduation Year'),
#   ('SKILLS', 'O'),
#   ('Requirement', 'B-Skills'),
#   ('Analysis', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('Sales', 'I-Skills'),
#   ('support', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('Test', 'I-Skills'),
#   ('Planning', 'I-Skills'),
#   ('Less', 'I-Skills'),
#   ('than', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('ADDITIONAL', 'O'),
#   ('INFORMATION', 'O'),
#   ('Skills', 'O'),
#   ('Bid', 'B-Skills'),
#   ('management', 'I-Skills'),
#   ('Sales', 'I-Skills'),
#   ('support', 'I-Skills'),
#   ('Requirement', 'I-Skills'),
#   ('Analysis', 'I-Skills'),
#   ('Test', 'I-Skills'),
#   ('Planning', 'I-Skills'),
#   ('and', 'I-Skills'),
#   ('Test', 'I-Skills'),
#   ('execution', 'L-Skills')],
#  [('Ayesha', 'B-Name'),
#   ('B', 'L-Name'),
#   ('Team', 'B-Designation'),
#   ('member', 'L-Designation'),
#   ('Oracle', 'U-Companies worked at'),
#   ('Bangalore', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('Email', 'O'),
#   ('me', 'O'),
#   ('on', 'O'),
#   ('Indeed', 'O'),
#   ('indeed.com/r/Ayesha-B/b2985be284dee3d6', 'U-Email Address'),
#   ('Seeking', 'O'),
#   ('a', 'O'),
#   ('position', 'O'),
#   ('to', 'O'),
#   ('utilise', 'O'),
#   ('my', 'O'),
#   ('skills', 'O'),
#   ('and', 'O'),
#   ('abilities', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('industry', 'O'),
#   ('that', 'O'),
#   ('offers', 'O'),
#   ('professional', 'O'),
#   ('growth', 'O'),
#   ('while', 'O'),
#   ('being', 'O'),
#   ('innovative', 'O'),
#   ('flexible', 'O'),
#   ('and', 'O'),
#   ('also', 'O'),
#   ('to', 'O'),
#   ('explore', 'O'),
#   ('myself', 'O'),
#   ('and', 'O'),
#   ('utilise', 'O'),
#   ('my', 'O'),
#   ('potential', 'O'),
#   ('to', 'O'),
#   ('the', 'O'),
#   ('growth', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('company', 'O'),
#   ('WORK', 'O'),
#   ('EXPERIENCE', 'O'),
#   ('Team', 'B-Designation'),
#   ('member', 'L-Designation'),
#   ('Oracle', 'U-Companies worked at'),
#   ('Bangalore', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('August', 'O'),
#   ('2012', 'O'),
#   ('to', 'O'),
#   ('Present', 'O'),
#   ('Nature', 'O'),
#   ('of', 'O'),
#   ('duties', 'O'),
#   ('Developed', 'O'),
#   ('and', 'O'),
#   ('deployed', 'O'),
#   ('Oracle', 'U-Companies worked at'),
#   ('forms', 'O'),
#   ('in', 'O'),
#   ('FLEXCUBE', 'O'),
#   ('CORPORATE', 'O'),
#   ('I', 'O'),
#   ('have', 'O'),
#   ('developed', 'O'),
#   ('Oracle', 'U-Companies worked at'),
#   ('Forms', 'O'),
#   ('and', 'O'),
#   ('deployed', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('in', 'O'),
#   ('application', 'O'),
#   ('server', 'O'),
#   ('which', 'O'),
#   ('is', 'O'),
#   ('used', 'O'),
#   ('as', 'O'),
#   ('front', 'O'),
#   ('end', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('bank', 'O'),
#   ('users', 'O'),
#   ('Necessary', 'O'),
#   ('coding', 'O'),
#   ('changes', 'O'),
#   ('of', 'O'),
#   ('project', 'O'),
#   ('are', 'O'),
#   ('done', 'O'),
#   ('in', 'O'),
#   ('PL', 'O'),
#   ('SQL', 'O'),
#   ('developer', 'O'),
#   ('Necessary', 'O'),
#   ('Procedures', 'O'),
#   ('and', 'O'),
#   ('Functions', 'O'),
#   ('are', 'O'),
#   ('defined', 'O'),
#   ('as', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('project', 'O'),
#   ('Was', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('Internal', 'O'),
#   ('Unit', 'O'),
#   ('Testing', 'O'),
#   ('and', 'O'),
#   ('Unit', 'O'),
#   ('Testing', 'O'),
#   ('I', 'O'),
#   ('have', 'O'),
#   ('prepared', 'O'),
#   ('Test', 'O'),
#   ('cases', 'O'),
#   ('for', 'O'),
#   ('forms', 'O'),
#   ('and', 'O'),
#   ('tested', 'O'),
#   ('the', 'O'),
#   ('same', 'O'),
#   ('and', 'O'),
#   ('was', 'O'),
#   ('part', 'O'),
#   ('of', 'O'),
#   ('Internal', 'O'),
#   ('Unit', 'O'),
#   ('Testing', 'O'),
#   ('Documentation', 'O'),
#   ('I', 'O'),
#   ('have', 'O'),
#   ('prepared', 'O'),
#   ('Functional', 'O'),
#   ('Specification', 'O'),
#   ('Desgin', 'O'),
#   ('Specification', 'O'),
#   ('and', 'O'),
#   ('Project', 'O'),
#   ('specification', 'O'),
#   ('documentation', 'O'),
#   ('Installed', 'O'),
#   ('and', 'O'),
#   ('worked', 'O'),
#   ('on', 'O'),
#   ('FLEXML', 'O'),
#   ('Exported', 'O'),
#   ('and', 'O'),
#   ('Imported', 'O'),
#   ('schemas', 'O'),
#   ('EDUCATION', 'O'),
#   ('B.E.', 'B-Degree'),
#   ('in', 'I-Degree'),
#   ('CSE', 'L-Degree'),
#   ('Atria', 'B-College Name'),
#   ('Institute', 'I-College Name'),
#   ('of', 'I-College Name'),
#   ('Technology', 'L-College Name'),
#   ('Bangalore', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('2012', 'O'),
#   ('Pre', 'B-College Name'),
#   ('University', 'I-College Name'),
#   ('Education', 'L-College Name'),
#   ('Bangalore', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('2008', 'O'),
#   ('C.B.S.E.', 'U-Degree'),
#   ('Sindhi', 'B-College Name'),
#   ('High', 'I-College Name'),
#   ('School', 'L-College Name'),
#   ('Bangalore', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('2006', 'O'),
#   ('https://www.indeed.com/r/Ayesha-B/b2985be284dee3d6?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('  ', 'O'),
#   ('ADDITIONAL', 'O'),
#   ('INFORMATION', 'O'),
#   ('SOFT', 'O'),
#   ('SKILLS', 'O'),
#   ('Sincere', 'I-Skills'),
#   ('and', 'I-Skills'),
#   ('Hardworking', 'I-Skills'),
#   ('in', 'I-Skills'),
#   ('nature', 'I-Skills'),
#   ('Highly', 'I-Skills'),
#   ('Dedicated', 'I-Skills'),
#   ('towards', 'I-Skills'),
#   ('work', 'I-Skills'),
#   ('Efficient', 'I-Skills'),
#   ('Individual', 'I-Skills'),
#   ('and', 'I-Skills'),
#   ('Team', 'I-Skills'),
#   ('Player', 'I-Skills'),
#   ('Goal', 'I-Skills'),
#   ('Oriented', 'I-Skills'),
#   ('Self', 'I-Skills'),
#   ('Motivated', 'I-Skills'),
#   ('IT', 'I-Skills'),
#   ('Literacy', 'L-Skills')],
#  [('Bhawana', 'B-Name'),
#   ('Daf', 'L-Name'),
#   ('Pune', 'U-Location'),
#   ('Maharashtra', 'O'),
#   ('Email', 'O'),
#   ('me', 'O'),
#   ('on', 'O'),
#   ('Indeed', 'O'),
#   ('indeed.com/r/Bhawana-Daf/d9ddb6a54519d583', 'U-Email Address'),
#   ('Seeking', 'O'),
#   ('a', 'O'),
#   ('career', 'O'),
#   ('in', 'O'),
#   ('preschool', 'O'),
#   ('where', 'O'),
#   ('I', 'O'),
#   ('can', 'O'),
#   ('utilize', 'O'),
#   ('my', 'O'),
#   ('teaching', 'O'),
#   ('background', 'O'),
#   ('strongly', 'O'),
#   ('in', 'O'),
#   ('nurturing', 'O'),
#   ('young', 'O'),
#   ('minds', 'O'),
#   ('demonstrating', 'O'),
#   ('quality', 'O'),
#   ('teaching', 'O'),
#   ('skills', 'O'),
#   ('Willing', 'O'),
#   ('to', 'O'),
#   ('relocate', 'O'),
#   ('to', 'O'),
#   ('Viman', 'O'),
#   ('Nagar', 'O'),
#   ('Maharashtra', 'O'),
#   ('Vadgaonsheri', 'O'),
#   ('Kharadi', 'O'),
#   ('Maharashtra', 'O'),
#   ('WORK', 'O'),
#   ('EXPERIENCE', 'O'),
#   ('Preschool', 'B-Designation'),
#   ('Teacher', 'L-Designation'),
#   ('Pune', 'U-Location'),
#   ('Maharashtra', 'O'),
#   ('2015', 'O'),
#   ('to', 'O'),
#   ('2018', 'O'),
#   ('Class', 'B-Designation'),
#   ('teacher', 'L-Designation'),
#   ('Data', 'O'),
#   ('Entry', 'O'),
#   ('and', 'O'),
#   ('Discrepancy', 'O'),
#   ('Management', 'O'),
#   ('Oracle', 'B-Companies worked at'),
#   ('Clinical', 'L-Companies worked at'),
#   ('4.6', 'O'),
#   ('Knowledge', 'O'),
#   ('of', 'O'),
#   ('clinical', 'O'),
#   ('trial', 'O'),
#   ('data', 'O'),
#   ('like', 'O'),
#   ('Demographic', 'O'),
#   ('Data', 'O'),
#   ('Adverse', 'O'),
#   ('Events', 'O'),
#   ('AE', 'O'),
#   ('Serious', 'O'),
#   ('Adverse', 'O'),
#   ('Events', 'O'),
#   ('SAE', 'O'),
#   ('Laboratory', 'O'),
#   ('Data', 'O'),
#   ('Lab', 'O'),
#   ('Data', 'O'),
#   ('etc', 'O'),
#   ('EDUCATION', 'O'),
#   ('B.', 'B-Degree'),
#   ('Sc', 'I-Degree'),
#   ('in', 'I-Degree'),
#   ('Biology', 'L-Degree'),
#   ('Government', 'B-College Name'),
#   ('Science', 'I-College Name'),
#   ('College', 'L-College Name'),
#   ('Pandhurna', 'O'),
#   ('Madhya', 'O'),
#   ('Pradesh', 'O'),
#   ('H.S.C', 'U-Degree'),
#   ('R.D.H.S.', 'B-College Name'),
#   ('School', 'L-College Name'),
#   ('Chhindwara', 'O'),
#   ('Madhya', 'O'),
#   ('Pradesh', 'O'),
#   ('Post', 'B-Degree'),
#   ('Graduate', 'I-Degree'),
#   ('Diploma', 'I-Degree'),
#   ('in', 'I-Degree'),
#   ('Clinical', 'I-Degree'),
#   ('Data', 'I-Degree'),
#   ('Management', 'L-Degree'),
#   ('R.D.H.S.', 'B-College Name'),
#   ('School', 'L-College Name'),
#   ('Chhindwara', 'O'),
#   ('Madhya', 'O'),
#   ('Pradesh', 'O'),
#   ('SKILLS', 'O'),
#   ('Teaching', 'U-Skills'),
#   ('3', 'O'),
#   ('years', 'O'),
#   ('ADDITIONAL', 'O'),
#   ('INFORMATION', 'O'),
#   ('SKILLS', 'O'),
#   ('Perform', 'O'),
#   ('all', 'O'),
#   ('functions', 'O'),
#   ('related', 'O'),
#   ('to', 'O'),
#   ('Data', 'O'),
#   ('Entry', 'O'),
#   ('like', 'O'),
#   ('First', 'O'),
#   ('Pass', 'O'),
#   ('and', 'O'),
#   ('Second', 'O'),
#   ('Pass', 'O'),
#   ('Data', 'O'),
#   ('Entry', 'O'),
#   ('review', 'O'),
#   ('of', 'O'),
#   ('Data', 'O'),
#   ('Entry', 'O'),
#   ('and', 'O'),
#   ('database', 'O'),
#   ('update', 'O'),
#   ('Well', 'O'),
#   ('versed', 'O'),
#   ('in', 'O'),
#   ('reading', 'O'),
#   ('hand', 'O'),
#   ('written', 'O'),
#   ('patient', 'O'),
#   ('documents', 'O'),
#   ('https://www.indeed.com/r/Bhawana-Daf/d9ddb6a54519d583?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('  ', 'O'),
#   ('Review', 'O'),
#   ('analyze', 'O'),
#   ('and', 'O'),
#   ('validate', 'O'),
#   ('clinical', 'O'),
#   ('trial', 'O'),
#   ('data', 'O'),
#   ('to', 'O'),
#   ('ensure', 'O'),
#   ('consistency', 'O'),
#   ('integrity', 'O'),
#   ('and', 'O'),
#   ('accuracy', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('project', 'O'),
#   ('specific', 'O'),
#   ('guidelines', 'O'),
#   ('Maintain', 'O'),
#   ('clinical', 'O'),
#   ('trial', 'O'),
#   ('data', 'O'),
#   ('accuracy', 'O'),
#   ('through', 'O'),
#   ('review', 'O'),
#   ('of', 'O'),
#   ('case', 'O'),
#   ('report', 'O'),
#   ('forms', 'O'),
#   ('for', 'O'),
#   ('completeness', 'O'),
#   ('and', 'O'),
#   ('consistency', 'O'),
#   ('Query', 'O'),
#   ('data', 'O'),
#   ('inconsistencies', 'O'),
#   ('and', 'O'),
#   ('revise', 'O'),
#   ('case', 'O'),
#   ('report', 'O'),
#   ('forms', 'O'),
#   ('in', 'O'),
#   ('compliance', 'O'),
#   ('with', 'O'),
#   ('standard', 'O'),
#   ('operating', 'O'),
#   ('procedures', 'O'),
#   ('client', 'O'),
#   ('guidelines', 'O'),
#   ('and', 'O'),
#   ('regulatory', 'O'),
#   ('agency', 'O'),
#   ('guidelines', 'O')],
#  [('Darshan', 'B-Name'),
#   ('G.', 'L-Name'),
#   ('Financial', 'B-Designation'),
#   ('Analyst', 'L-Designation'),
#   ('Oracle', 'U-Companies worked at'),
#   ('Bengaluru', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('Email', 'O'),
#   ('me', 'O'),
#   ('on', 'O'),
#   ('Indeed', 'O'),
#   ('indeed.com/r/Darshan-G/025a61a82c6a8c5a', 'U-Location'),
#   ('Hard', 'O'),
#   ('worker', 'O'),
#   ('Patience', 'O'),
#   ('and', 'O'),
#   ('Good', 'O'),
#   ('commitment', 'O'),
#   ('I', 'O'),
#   ('here', 'O'),
#   ('by', 'O'),
#   ('declare', 'O'),
#   ('that', 'O'),
#   ('the', 'O'),
#   ('above', 'O'),
#   ('furnished', 'O'),
#   ('details', 'O'),
#   ('are', 'O'),
#   ('true', 'O'),
#   ('up', 'O'),
#   ('to', 'O'),
#   ('my', 'O'),
#   ('knowledge', 'O'),
#   ('Place', 'O'),
#   ('Bangalore', 'O'),
#   ('Darshan', 'O'),
#   ('M', 'O'),
#   ('G', 'O'),
#   ('Date', 'O'),
#   ('Signature', 'O'),
#   ('WORK', 'O'),
#   ('EXPERIENCE', 'O'),
#   ('Financial', 'B-Designation'),
#   ('Analyst', 'L-Designation'),
#   ('Oracle', 'U-Companies worked at'),
#   ('June', 'O'),
#   ('2015', 'O'),
#   ('to', 'O'),
#   ('Present', 'O'),
#   ('Roles', 'O'),
#   ('and', 'O'),
#   ('responsibilities', 'O'),
#   ('Auditing', 'O'),
#   ('As', 'O'),
#   ('per', 'O'),
#   ('T', 'O'),
#   ('E', 'O'),
#   ('claims', 'O'),
#   ('Catalogues', 'O'),
#   ('Export', 'O'),
#   ('import', 'O'),
#   ('activity', 'O'),
#   ('Payment', 'O'),
#   ('validation', 'O'),
#   ('Fall', 'O'),
#   ('back', 'O'),
#   ('audits', 'O'),
#   ('Manual', 'O'),
#   ('expenses', 'O'),
#   ('Inactive', 'O'),
#   ('employees', 'O'),
#   ('Handing', 'O'),
#   ('queries', 'O'),
#   ('E', 'O'),
#   ('mails', 'O'),
#   ('Invoice', 'O'),
#   ('processing', 'O'),
#   ('Handing', 'O'),
#   ('payment', 'O'),
#   ('queries', 'O'),
#   ('Fringe', 'O'),
#   ('benefit', 'O'),
#   ('tax', 'O'),
#   ('Carrier', 'O'),
#   ('Achievements', 'O'),
#   ('Received', 'O'),
#   ('Numerous', 'O'),
#   ('Monthly', 'O'),
#   ('and', 'O'),
#   ('Quarterly', 'O'),
#   ('awards', 'O'),
#   ('for', 'O'),
#   ('completing', 'O'),
#   ('assigned', 'O'),
#   ('task', 'O'),
#   ('on', 'O'),
#   ('time', 'O'),
#   ('Received', 'O'),
#   ('numerous', 'O'),
#   ('appreciation', 'O'),
#   ('emails', 'O'),
#   ('from', 'O'),
#   ('Vendors', 'O'),
#   ('for', 'O'),
#   ('making', 'O'),
#   ('On', 'O'),
#   ('Time', 'O'),
#   ('Payment', 'O'),
#   ('Received', 'O'),
#   ('appreciations', 'O'),
#   ('emails', 'O'),
#   ('from', 'O'),
#   ('Supervisor', 'O'),
#   ('for', 'O'),
#   ('knowing', 'O'),
#   ('End', 'O'),
#   ('to', 'O'),
#   ('End', 'O'),
#   ('process', 'O'),
#   ('and', 'O'),
#   ('first', 'O'),
#   ('point', 'O'),
#   ('of', 'O'),
#   ('contact', 'O'),
#   ('person', 'O'),
#   ('for', 'O'),
#   ('any', 'O'),
#   ('escalation', 'O'),
#   ('Submitted', 'O'),
#   ('Innovative', 'O'),
#   ('ideas', 'O'),
#   ('to', 'O'),
#   ('improve', 'O'),
#   ('the', 'O'),
#   ('process', 'O'),
#   ('efficiency', 'O'),
#   ('and', 'O'),
#   ('nominated', 'O'),
#   ('for', 'O'),
#   ('Internal', 'O'),
#   ('Award', 'O'),
#   ('Process', 'B-Designation'),
#   ('associate', 'L-Designation'),
#   ('Accenture', 'U-Companies worked at'),
#   ('February', 'O'),
#   ('2014', 'O'),
#   ('to', 'O'),
#   ('May', 'O'),
#   ('2015', 'O'),
#   ('Roles', 'O'),
#   ('Responsibility', 'O'),
#   ('Invoice', 'O'),
#   ('backlog', 'O'),
#   ('Overall', 'O'),
#   ('hold', 'O'),
#   ('summary', 'O'),
#   ('Payment', 'O'),
#   ('rejections', 'O'),
#   ('Requiting', 'O'),
#   ('backlog', 'O'),
#   ('report', 'O'),
#   ('https://www.indeed.com/r/Darshan-G/025a61a82c6a8c5a?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('  ', 'O'),
#   ('PO', 'O'),
#   ('stuck', 'O'),
#   ('Expense', 'O'),
#   ('hold', 'O'),
#   ('Bank', 'O'),
#   ('details', 'O'),
#   ('invalid', 'O'),
#   ('Schedule', 'O'),
#   ('payment', 'O'),
#   ('hold', 'O'),
#   ('Work', 'O'),
#   ('flow', 'O'),
#   ('Daily', 'O'),
#   ('report', 'O'),
#   ('status', 'O'),
#   ('Dash', 'O'),
#   ('board', 'O'),
#   ('update', 'O'),
#   ('EDUCATION', 'O'),
# ...
#   ('the', 'O'),
#   ('invoicing', 'O'),
#   ('activity', 'O'),
#   ('as', 'O'),
#   ('an', 'O'),
#   ('anchor', 'O'),
#   ('to', 'O'),
#   ('send', 'O'),
#   ('the', 'O'),
#   ('invoices', 'O'),
#   ('communicate', 'O'),
#   ('with', 'O'),
#   ('client', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('issues', 'O'),
#   ('or', 'O'),
#   ('any', 'O'),
#   ('mismatches', 'O'),
#   ('in', 'O'),
#   ('billing', 'O'),
#   ('amount', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('calculations', 'O'),
#   ('Acted', 'O'),
#   ('as', 'O'),
#   ('liaison', 'O'),
#   ('amongst', 'O'),
#   ('lines', 'O'),
#   ('of', 'O'),
#   ('business', 'O'),
#   ('developers', 'O'),
#   ('testers', 'O'),
#   ('and', 'O'),
#   ('senior', 'O'),
#   ('project', 'O'),
#   ('managers', 'O'),
#   ('Environment', 'O'),
#   ('PBS', 'O'),
#   ('Project', 'O'),
#   ('budgeting', 'O'),
#   ('systems', 'O'),
#   ('ECMS', 'O'),
#   ('External', 'O'),
#   ('consultants', 'O'),
#   ('and', 'O'),
#   ('vendor', 'O'),
#   ('managements', 'O'),
#   ('systems', 'O'),
#   ('ALCON', 'O'),
#   ('Allocation', 'O'),
#   ('and', 'O'),
#   ('confirmation', 'O'),
#   ('IPM+', 'O'),
#   ('Integrated', 'O'),
#   ('Project', 'O'),
#   ('management', 'O'),
#   ('PMO', 'U-Designation'),
#   ('Cloud', 'O'),
#   ('Infrastructure', 'O'),
#   ('Services', 'O'),
#   ('Infosys', 'B-Companies worked at'),
#   ('BPO', 'I-Companies worked at'),
#   ('Ltd', 'L-Companies worked at'),
#   ('Bengaluru', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('December', 'O'),
#   ('2015', 'O'),
#   ('to', 'O'),
#   ('September', 'O'),
#   ('2016', 'O'),
#   ('Responsibilities', 'O'),
#   ('Project', 'O'),
#   ('Management', 'O'),
#   ('Operations', 'O'),
#   ('Team', 'O'),
#   ('as', 'O'),
#   ('PMO', 'U-Designation'),
#   ('supporting', 'O'),
#   ('the', 'O'),
#   ('Project', 'O'),
#   ('delivery', 'O'),
#   ('team', 'O'),
#   ('Tracking', 'O'),
#   ('BE', 'O'),
#   ('reports', 'O'),
#   ('creating', 'O'),
#   ('Invoices', 'O'),
#   ('working', 'O'),
#   ('on', 'O'),
#   ('reports', 'O'),
#   ('related', 'O'),
#   ('to', 'O'),
#   ('project', 'O'),
#   ('management', 'O'),
#   ('Project', 'O'),
#   ('Management', 'O'),
#   ('Deutsche', 'O'),
#   ('Bank', 'O'),
#   ('Infosys', 'B-Companies worked at'),
#   ('BPO', 'I-Companies worked at'),
#   ('Ltd', 'L-Companies worked at'),
#   ('Bengaluru', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('June', 'O'),
#   ('2013', 'O'),
#   ('to', 'O'),
#   ('October', 'O'),
#   ('2015', 'O'),
#   ('Bangalore', 'O'),
#   ('Jun', 'O'),
#   ('2013', 'O'),
#   ('Oct', 'O'),
#   ('2015', 'O'),
#   ('Responsibilities', 'O'),
#   ('Responsible', 'O'),
#   ('to', 'O'),
#   ('Communicate', 'O'),
#   ('with', 'O'),
#   ('internal', 'O'),
#   ('customers', 'O'),
#   ('and', 'O'),
#   ('client', 'O'),
#   ('on', 'O'),
#   ('boarding', 'O'),
#   ('related', 'O'),
#   ('activities', 'O'),
#   ('Worked', 'O'),
#   ('on', 'O'),
#   ('Project', 'O'),
#   ('Management', 'O'),
#   ('tools', 'O'),
#   ('used', 'O'),
#   ('for', 'O'),
#   ('Allocations', 'O'),
#   ('and', 'O'),
#   ('Project', 'O'),
#   ('planning', 'O'),
#   ('Worked', 'O'),
#   ('on', 'O'),
#   ('MIS', 'O'),
#   ('MSA', 'O'),
#   ('reports', 'O'),
#   ('Setting', 'O'),
#   ('up', 'O'),
#   ('reports', 'O'),
#   ('Summary', 'O'),
#   ('reports', 'O'),
#   ('dashboards', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('Service', 'O'),
#   ('Now', 'O'),
#   ('Tickets', 'O'),
#   ('monitoring', 'O'),
#   ('and', 'O'),
#   ('sending', 'O'),
#   ('data', 'O'),
#   ('to', 'O'),
#   ('clients', 'O'),
#   ('Provisioned', 'O'),
#   ('Secure', 'O'),
#   ('ID', 'O'),
#   ('tokens', 'O'),
#   ('Virtual', 'O'),
#   ('desktops', 'O'),
#   ('to', 'O'),
#   ('team', 'O'),
#   ('members', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('DB', 'O'),
#   ('Build', 'O'),
#   ('team', 'O'),
#   ('Handled', 'O'),
#   ('incident', 'O'),
#   ('and', 'O'),
#   ('service', 'O'),
#   ('tickets', 'O'),
#   ('for', 'O'),
#   ('application', 'O'),
#   ('related', 'O'),
#   ('access', 'O'),
#   ('and', 'O'),
#   ('other', 'O'),
#   ('requirements', 'O'),
#   ('Financial', 'O'),
#   ('Analyst', 'O'),
#   ('for', 'O'),
#   ('AMEX', 'O'),
#   ('in', 'O'),
#   ('iFIND', 'O'),
#   ('   ', 'O'),
#   ('American', 'O'),
#   ('Express', 'O'),
#   ('Infosys', 'B-Companies worked at'),
#   ('BPO', 'I-Companies worked at'),
#   ('Ltd', 'L-Companies worked at'),
#   ('Bengaluru', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('February', 'O'),
#   ('2012', 'O'),
#   ('to', 'O'),
#   ('May', 'O'),
#   ('2013', 'O'),
#   ('team', 'O'),
#   ('Issue', 'O'),
#   ('Filter', 'O'),
#   ('and', 'O'),
#   ('Detection', 'O'),
#   ('Team', 'O'),
#   ('In', 'O'),
#   ('iFIND', 'O'),
#   ('team', 'O'),
#   ('worked', 'O'),
#   ('in', 'O'),
#   ('CRL', 'O'),
#   ('applications', 'O'),
#   ('Co', 'O'),
#   ('brand', 'O'),
#   ('Rebates', 'O'),
#   ('LAA', 'O'),
#   ('to', 'O'),
#   ('retrieve', 'O'),
#   ('Metrics', 'O'),
#   ('data', 'O'),
#   ('from', 'O'),
#   ('Mainframe', 'O'),
#   ('for', 'O'),
#   ('different', 'O'),
#   ('functionalities', 'O'),
#   ('Handled', 'O'),
#   ('the', 'O'),
#   ('Admin', 'O'),
#   ('Q', 'O'),
#   ('entries', 'O'),
#   ('in', 'O'),
#   ('Oracle', 'O'),
#   ('BPM', 'O'),
#   ('Tool', 'O'),
#   ('for', 'O'),
#   ('Product', 'O'),
#   ('Transfer', 'O'),
#   ('scenarios', 'O'),
#   ('of', 'O'),
#   ('a', 'O'),
#   ('Card', 'O'),
#   ('Member', 'O'),
#   ('enrolled', 'O'),
#   ('in', 'O'),
#   ('AMEX', 'O'),
#   ('Involved', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('conference', 'O'),
#   ('calls', 'O'),
#   ('with', 'O'),
#   ('client', 'O'),
#   ('to', 'O'),
#   ('discuss', 'O'),
#   ('and', 'O'),
#   ('review', 'O'),
#   ('about', 'O'),
#   ('the', 'O'),
#   ('different', 'O'),
#   ('rejects', 'O'),
#   ('in', 'O'),
#   ('CRL', 'O'),
#   ('PT', 'O'),
#   ('to', 'O'),
#   ('caused', 'O'),
#   ('due', 'O'),
#   ('to', 'O'),
#   ('application', 'O'),
#   ('specific', 'O'),
#   ('error', 'O'),
#   ('Liaised', 'O'),
#   ('and', 'O'),
#   ('followed', 'O'),
#   ('up', 'O'),
#   ('with', 'O'),
#   ('IT', 'O'),
#   ('support', 'O'),
#   ('teams', 'O'),
#   ('to', 'O'),
#   ('solve', 'O'),
#   ('the', 'O'),
#   ('issues', 'O'),
#   ('in', 'O'),
#   ('applications', 'O'),
#   ('Contract', 'O'),
#   ('employee', 'O'),
#   ('for', 'O'),
#   ('JPM', 'O'),
#   ('through', 'O'),
#   ('Infosys', 'O'),
#   ('JP', 'O'),
#   ('Morgan', 'O'),
#   ('Chase', 'O'),
#   ('Infosys', 'B-Companies worked at'),
#   ('BPO', 'I-Companies worked at'),
#   ('Ltd', 'L-Companies worked at'),
#   ('Bengaluru', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('April', 'O'),
#   ('2011', 'O'),
#   ('to', 'O'),
#   ('January', 'O'),
#   ('2012', 'O'),
#   ('Bangalore', 'O'),
#   ('Apr', 'O'),
#   ('2011', 'O'),
#   ('Jan', 'O'),
#   ('2012', 'O'),
#   ('Responsibilities', 'O'),
#   ('Responsible', 'O'),
#   ('to', 'O'),
#   ('remediate', 'O'),
#   ('the', 'O'),
#   ('Third', 'O'),
#   ('Party', 'O'),
#   ('Brokerage', 'O'),
#   ('rates', 'O'),
#   ('for', 'O'),
#   ('executing', 'O'),
#   ('brokers', 'O'),
#   ('where', 'O'),
#   ('JPM', 'O'),
#   ('is', 'O'),
#   ('a', 'O'),
#   ('clearing', 'O'),
#   ('broker', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('Triparty', 'O'),
#   ('EGUS', 'O'),
#   ('agreement', 'O'),
#   ('in', 'O'),
#   ('Futures', 'O'),
#   ('Options', 'O'),
#   ('contracts', 'O'),
#   ('under', 'O'),
#   ('Brokerage', 'O'),
#   ('team', 'O'),
#   ('Worked', 'O'),
#   ('as', 'O'),
#   ('Contract', 'O'),
#   ('employee', 'O'),
#   ('for', 'O'),
#   ('JPM', 'O'),
#   ('through', 'O'),
#   ('Infosys', 'O'),
#   ('Process', 'O'),
#   ('Specialist', 'O'),
#   ('Select', 'O'),
#   ('Portfolio', 'O'),
#   ('Servicing', 'O'),
#   ('Mortgage-', 'O'),
#   ('Infosys', 'B-Companies worked at'),
#   ('BPO', 'I-Companies worked at'),
#   ('Ltd', 'L-Companies worked at'),
#   ('Bengaluru', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('November', 'O'),
#   ('2008', 'O'),
#   ('to', 'O'),
#   ('March', 'O'),
#   ('2011', 'O'),
#   ('Responsibilities', 'O'),
#   ('In', 'O'),
#   ('REO', 'O'),
#   ('Team', 'O'),
#   ('Real', 'O'),
#   ('Estate', 'O'),
#   ('Owned', 'O'),
#   ('worked', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('process', 'O'),
#   ('to', 'O'),
#   ('Approve', 'O'),
#   ('Invoices', 'O'),
#   ('from', 'O'),
#   ('the', 'O'),
#   ('brokers', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('expenses', 'O'),
#   ('incurred', 'O'),
#   ('by', 'O'),
#   ('SPS', 'O'),
#   ('on', 'O'),
#   ('the', 'O'),
#   ('property', 'O'),
#   ('which', 'O'),
#   ('they', 'O'),
#   ('own', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('Foreclosure', 'O'),
#   ('sale', 'O'),
#   ('Create', 'O'),
#   ('Checks', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('Invoices', 'O'),
#   ('of', 'O'),
#   ('HOA', 'O'),
#   ('Home', 'O'),
#   ('Owners', 'O'),
#   ('Associations', 'O'),
#   ('sent', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('Attorneys', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('state', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('property', 'O'),
#   ('foreclosed', 'O'),
#   ('by', 'O'),
#   ('SPS', 'O'),
#   ('in', 'O'),
#   ('the', 'O'),
#   ('foreclosure', 'O'),
#   ('The', 'O'),
#   ('bill', 'O'),
#   ('is', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('maintenance', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('property', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('HOA', 'O'),
#   ('Senior', 'O'),
#   ('Process', 'O'),
#   ('Associate', 'O'),
#   ('UBS-', 'O'),
#   ('Infosys', 'B-Companies worked at'),
#   ('BPO', 'I-Companies worked at'),
#   ('Ltd', 'L-Companies worked at'),
#   ('Bengaluru', 'U-Location'),
#   ('Karnataka', 'O'),
#   ('October', 'O'),
#   ('2004', 'U-Years of Experience'),
#   ('to', 'O'),
#   ('October', 'O'),
#   ('2008', 'O'),
#   ('Responsibilities', 'O'),
#   ('Instrument', 'O'),
#   ('Data', 'O'),
#   ('Strategy', 'O'),
#   ('and', 'O'),
#   ('Analytics', 'O'),
#   ('Create', 'O'),
#   ('new', 'O'),
#   ('securities', 'O'),
#   ('Bonds', 'O'),
#   ('and', 'O'),
#   ('Futures', 'O'),
#   ('in', 'O'),
#   ('DMSI', 'O'),
#   ('database', 'O'),
#   ('based', 'O'),
#   ('on', 'O'),
#   ('Securities', 'O'),
#   ('Data', 'O'),
#   ('provider', 'O'),
#   ('Bloomberg', 'O'),
#   ('Telekurs', 'O'),
#   ('International', 'O'),
#   ('and', 'O'),
#   ('Euro', 'O'),
#   ('clear', 'O'),
#   ('and', 'O'),
#   ('the', 'O'),
#   ('information', 'O'),
#   ('provided', 'O'),
#   ('by', 'O'),
#   ('the', 'O'),
#   ('trading', 'O'),
#   ('desk', 'O'),
#   ('Worked', 'O'),
#   ('in', 'O'),
#   ('Account', 'O'),
#   ('openings', 'O'),
#   ('of', 'O'),
#   ('Institutional', 'O'),
#   ('Wholesale', 'O'),
#   ('FITS', 'O'),
#   ('accounts', 'O'),
#   ('in', 'O'),
#   ('Master', 'O'),
#   ('files', 'O'),
#   ('APAC', 'O'),
#   ('and', 'O'),
#   ('Shares', 'O'),
#   ('AU', 'O'),
#   ('and', 'O'),
#   ('NZ', 'O'),
#   ('also', 'O'),
#   ('learnt', 'O'),
#   ('to', 'O'),
#   ('use', 'O'),
#   ('Shares', 'O'),
#   ('and', 'O'),
#   ('Australian', 'O'),
#   ('Fixed', 'O'),
#   ('Income', 'O'),
#   ('trading', 'O'),
#   ('system', 'O'),
#   ('   ', 'O'),
#   ('Provide', 'O'),
#   ('the', 'O'),
#   ('Correct', 'O'),
#   ('information', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('securities', 'O'),
#   ('Issuer', 'O'),
#   ('Coupon', 'O'),
#   ('details', 'O'),
#   ('etc', 'O'),
#   ('to', 'O'),
#   ('downstream', 'O'),
#   ('trading', 'O'),
#   ('systems', 'O'),
#   ('like', 'O'),
#   ('FOS', 'O'),
#   ('Martini', 'O'),
#   ('Julius', 'O'),
#   ('Ransom', 'O'),
#   ('and', 'O'),
#   ('Global', 'O'),
#   ('1', 'O'),
#   ('Worked', 'O'),
#   ('in', 'O'),
#   ('Intersystem', 'O'),
#   ('controls', 'O'),
#   ('team', 'O'),
#   ('performing', 'O'),
#   ('Cash', 'O'),
#   ('and', 'O'),
#   ('Stock', 'O'),
#   ('reconciliations', 'O'),
#   ('between', 'O'),
#   ('the', 'O'),
#   ('system', 'O'),
#   ('COLT', 'O'),
#   ('Continuous', 'O'),
#   ('online', 'O'),
#   ('trading', 'O'),
#   ('and', 'O'),
#   ('SSE', 'O'),
#   ('Securities', 'O'),
#   ...],
#  [('Pradeep', 'B-Name'),
#   ('Kumar', 'L-Name'),
#   ('Security', 'B-Designation'),
#   ('Analyst', 'L-Designation'),
#   ('in', 'O'),
#   ('Infosys', 'B-Companies worked at'),
#   ('Career', 'I-Companies worked at'),
#   ('Contour', 'L-Companies worked at'),
#   ('Hyderabad', 'O'),
#   ('Telangana', 'O'),
#   ('Telangana', 'O'),
#   ('Email', 'O'),
#   ('me', 'O'),
#   ('on', 'O'),
#   ('Indeed', 'O'),
#   ('indeed.com/r/Pradeep-', 'O'),
#   ('Kumar/96485546eadd9488', 'O'),
#   ('WORK', 'O'),
#   ('EXPERIENCE', 'O'),
#   ('Security', 'B-Designation'),
#   ('Analyst', 'L-Designation'),
#   ('in', 'O'),
#   ('Infosys', 'O'),
#   ('Career', 'O'),
#   ('Contour', 'O'),
#   ('March', 'O'),
#   ('2015', 'O'),
#   ('to', 'O'),
#   ('Present', 'O'),
#   ('Security', 'O'),
#   ('incident', 'O'),
#   ('and', 'O'),
#   ('event', 'O'),
#   ('management', 'O'),
#   ('SIEM', 'O'),
#   ('is', 'O'),
#   ('the', 'O'),
#   ('process', 'O'),
#   ('of', 'O'),
#   ('identifying', 'O'),
#   ('monitoring', 'O'),
#   ('and', 'O'),
#   ('analysing', 'O'),
#   ('security', 'O'),
#   ('events', 'O'),
#   ('or', 'O'),
#   ('incidents', 'O'),
#   ('within', 'O'),
#   ('a', 'O'),
#   ('real', 'O'),
#   ('time', 'O'),
#   ('IT', 'O'),
#   ('environment', 'O'),
#   ('It', 'O'),
#   ('provides', 'O'),
#   ('centralized', 'O'),
#   ('view', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('security', 'O'),
#   ('scenario', 'O'),
#   ('of', 'O'),
#   ('an', 'O'),
#   ('IT', 'O'),
#   ('infrastructure', 'O'),
#   ('EDUCATION', 'O'),
#   ('B-', 'B-Degree'),
#   ('Tech', 'L-Degree'),
#   ('Jawaharlal', 'B-College Name'),
#   ('Nehru', 'I-College Name'),
#   ('Technological', 'I-College Name'),
#   ('University', 'L-College Name'),
#   ('Hyderabad', 'O'),
#   ('Telangana', 'O'),
#   ('SKILLS', 'O'),
#   ('Splunk', 'B-Skills'),
#   ('Network', 'I-Skills'),
#   ('Security', 'I-Skills'),
#   ('Arc', 'I-Skills'),
#   ('sight', 'I-Skills'),
#   ('2', 'I-Skills'),
#   ('years', 'I-Skills'),
#   ('SIEM', 'I-Skills'),
#   ('2', 'I-Skills'),
#   ('years', 'I-Skills'),
#   ('McAfee', 'I-Skills'),
#   ('ESM', 'I-Skills'),
#   ('1', 'I-Skills'),
#   ('year', 'I-Skills'),
#   ('ADDITIONAL', 'O'),
#   ('INFORMATION', 'O'),
#   ('Technologies', 'O'),
#   ('McAfee', 'O'),
#   ('SIEM', 'O'),
#   ('Arc', 'O'),
#   ('sight', 'O'),
#   ('HP', 'O'),
#   ('Service', 'O'),
#   ('manager', 'O'),
#   ('Description', 'O'),
#   ('Security', 'O'),
#   ('incident', 'O'),
#   ('and', 'O'),
#   ('event', 'O'),
#   ('management', 'O'),
#   ('SIEM', 'O'),
#   ('is', 'O'),
#   ('the', 'O'),
#   ('process', 'O'),
#   ('of', 'O'),
#   ('identifying', 'O'),
#   ('monitoring', 'O'),
#   ('and', 'O'),
#   ('analysing', 'O'),
#   ('security', 'O'),
#   ('events', 'O'),
#   ('or', 'O'),
#   ('incidents', 'O'),
#   ('within', 'O'),
#   ('a', 'O'),
#   ('real', 'O'),
#   ('time', 'O'),
#   ('IT', 'O'),
#   ('environment', 'O'),
#   ('It', 'O'),
#   ('provides', 'O'),
#   ('centralized', 'O'),
#   ('view', 'O'),
#   ('of', 'O'),
#   ('the', 'O'),
#   ('security', 'O'),
#   ('scenario', 'O'),
#   ('of', 'O'),
#   ('an', 'O'),
#   ('IT', 'O'),
#   ('infrastructure', 'O'),
#   ('Roles', 'O'),
#   ('and', 'O'),
#   ('Responsibilities', 'O'),
#   ('Have', 'O'),
#   ('Experience', 'O'),
#   ('in', 'O'),
#   ('device', 'O'),
#   ('integration', 'O'),
#   ('alarm', 'O'),
#   ('creation', 'O'),
#   ('in', 'O'),
#   ('ESM', 'O'),
#   ('Having', 'O'),
#   ('Experience', 'O'),
#   ('on', 'O'),
#   ('analysing', 'O'),
#   ('FIREWALL', 'O'),
#   ('events', 'O'),
#   ('Checking', 'O'),
#   ('health', 'O'),
#   ('status', 'O'),
#   ('for', 'O'),
#   ('all', 'O'),
#   ('devices', 'O'),
#   ('in', 'O'),
#   ('ESM', 'O'),
#   ('Working', 'O'),
#   ('in', 'O'),
#   ('Offshore', 'O'),
#   ('SOC', 'O'),
#   ('team', 'O'),
#   ('Monitoring', 'O'),
#   ('of', 'O'),
#   ('SOC', 'O'),
#   ('events', 'O'),
#   ('detecting', 'O'),
#   ('and', 'O'),
#   ('preventing', 'O'),
#   ('the', 'O'),
#   ('Intrusion', 'O'),
#   ('attempts', 'O'),
#   ('Hands', 'O'),
#   ('on', 'O'),
#   ('experience', 'O'),
#   ('monitoring', 'O'),
#   ('the', 'O'),
#   ('SIEM', 'O'),
#   ('tool', 'O'),
#   ('Provide', 'O'),
#   ('level', 'O'),
#   ('2', 'O'),
#   ('supports', 'O'),
#   ('to', 'O'),
#   ('manage', 'O'),
#   ('SIEM', 'O'),
#   ('components', 'O'),
#   ('Creating', 'O'),
#   ('reports', 'O'),
#   ('as', 'O'),
#   ('per', 'O'),
#   ('client', 'O'),
#   ('requirement', 'O'),
#   ('Analysing', 'O'),
#   ('daily', 'O'),
#   ('weekly', 'O'),
#   ('and', 'O'),
#   ('monthly', 'O'),
#   ('reports', 'O'),
#   ('Creating', 'O'),
#   ('case', 'O'),
#   ('for', 'O'),
#   ('the', 'O'),
#   ('suspicious', 'O'),
#   ('issue', 'O'),
#   ('and', 'O'),
#   ('forwarding', 'O'),
#   ('it', 'O'),
#   ('to', 'O'),
#   ('Onsite', 'O'),
#   ('SOC', 'O'),
#   ('team', 'O'),
#   ('for', 'O'),
#   ('further', 'O'),
#   ('investigation', 'O'),
#   ('Monitoring', 'O'),
#   ('the', 'O'),
#   ('events', 'O'),
#   ('on', 'O'),
#   ('SIEM', 'O'),
#   ('tool', 'O'),
#   ('Creating', 'O'),
#   ('the', 'O'),
#   ('tickets', 'O'),
#   ('in', 'O'),
#   ('ticketing', 'O'),
#   ('tool', 'O'),
#   ('https://www.indeed.com/r/Pradeep-Kumar/96485546eadd9488?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('https://www.indeed.com/r/Pradeep-Kumar/96485546eadd9488?isid=rex-download&ikw=download-top&co=IN',
#    'O'),
#   ('  ', 'O'),
#   ('Finding', 'O'),
#   ('false', 'O'),
#   ('positive', 'O'),
#   ('fine', 'O'),
#   ('tuning', 'O'),
#   ('and', 'O'),
#   ('escalating', 'O'),
#   ('Security', 'O'),
#   ('events', 'O')]]

# %%
spacy_data1 = []
for example in spacy_data:
    text = ""
    entities = []
    start = 0
    for w, t in example:
        text += w + " "
        if t != "O":
            entities.append((start, start + len(w), t[2: ]))
        start += len(w) + 1
    spacy_data1.append((text, {"entities": entities}))

spacy_data1[0]
# Out:
# ("Abhishek Jha Application Development Associate - Accenture   Bengaluru , Karnataka - Email me on Indeed : indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a   • To work for an organization which provides me the opportunity to improve my skills and knowledge for my individual and company 's growth in best possible ways .   Willing to relocate to : Bangalore , Karnataka   WORK EXPERIENCE   Application Development Associate   Accenture -   November 2017 to Present   Role : Currently working on Chat - bot . Developing Backend Oracle PeopleSoft Queries for the Bot which will be triggered based on given input . Also , Training the bot for different possible utterances ( Both positive and negative ) , which will be given as input by the user .   EDUCATION   B.E in Information science and engineering   B.v.b college of engineering and technology -   Hubli , Karnataka   August 2013 to June 2017   12th in Mathematics   Woodbine modern school   April 2011 to March 2013   10th   Kendriya Vidyalaya   April 2001 to March 2011   SKILLS   C ( Less than 1 year ) , Database ( Less than 1 year ) , Database Management ( Less than 1 year ) , Database Management System ( Less than 1 year ) , Java ( Less than 1 year )   ADDITIONAL INFORMATION   Technical Skills   https://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN    • Programming language : C , C++ , Java • Oracle PeopleSoft • Internet Of Things • Machine Learning • Database Management System • Computer Networks • Operating System worked on : Linux , Windows , Mac   Non - Technical Skills   • Honest and Hard - Working • Tolerant and Flexible to Different Situations • Polite and Calm • Team - Player ",
#  {'entities': [(0, 8, 'Name'),
#    (9, 12, 'Name'),
#    (13, 24, 'Designation'),
#    (25, 36, 'Designation'),
#    (37, 46, 'Designation'),
#    (49, 58, 'Companies worked at'),
#    (61, 70, 'Location'),
#    (97, 103, 'Email Address'),
#    (106, 148, 'Email Address'),
#    (383, 394, 'Designation'),
#    (395, 406, 'Designation'),
#    (407, 416, 'Designation'),
#    (419, 428, 'Companies worked at'),
#    (753, 756, 'Designation'),
#    (757, 759, 'Designation'),
#    (760, 771, 'Designation'),
#    (772, 779, 'Designation'),
#    (780, 783, 'Designation'),
#    (784, 795, 'Designation'),
#    (798, 803, 'College Name'),
#    (804, 811, 'College Name'),
#    (812, 814, 'College Name'),
#    (815, 826, 'College Name'),
#    (827, 830, 'College Name'),
#    (831, 841, 'College Name'),
#    (886, 890, 'Graduation Year'),
#    (915, 923, 'College Name'),
#    (924, 930, 'College Name'),
#    (931, 937, 'College Name'),
#    (974, 982, 'College Name'),
#    (983, 992, 'College Name'),
#    (1031, 1032, 'Skills'),
#    (1035, 1039, 'Skills'),
#    (1040, 1044, 'Skills'),
#    (1045, 1046, 'Skills'),
#    (1047, 1051, 'Skills'),
#    (1056, 1064, 'Skills'),
#    (1067, 1071, 'Skills'),
#    (1072, 1076, 'Skills'),
#    (1077, 1078, 'Skills'),
#    (1079, 1083, 'Skills'),
#    (1088, 1096, 'Skills'),
#    (1097, 1107, 'Skills'),
#    (1110, 1114, 'Skills'),
#    (1115, 1119, 'Skills'),
#    (1120, 1121, 'Skills'),
#    (1122, 1126, 'Skills'),
#    (1131, 1139, 'Skills'),
#    (1140, 1150, 'Skills'),
#    (1151, 1157, 'Skills'),
#    (1160, 1164, 'Skills'),
#    (1165, 1169, 'Skills'),
#    (1170, 1171, 'Skills'),
#    (1172, 1176, 'Skills'),
#    (1181, 1185, 'Skills'),
#    (1188, 1192, 'Skills'),
#    (1193, 1197, 'Skills'),
#    (1198, 1199, 'Skills'),
#    (1200, 1204, 'Skills'),
#    (1354, 1365, 'Skills'),
#    (1366, 1374, 'Skills'),
#    (1377, 1378, 'Skills'),
#    (1381, 1384, 'Skills'),
#    (1387, 1391, 'Skills'),
#    (1394, 1400, 'Skills'),
#    (1401, 1411, 'Skills'),
#    (1414, 1422, 'Skills'),
#    (1423, 1425, 'Skills'),
#    (1426, 1432, 'Skills'),
#    (1435, 1442, 'Skills'),
#    (1443, 1451, 'Skills'),
#    (1454, 1462, 'Skills'),
#    (1463, 1473, 'Skills'),
#    (1474, 1480, 'Skills'),
#    (1483, 1491, 'Skills'),
#    (1492, 1500, 'Skills'),
#    (1503, 1512, 'Skills'),
#    (1513, 1519, 'Skills'),
#    (1520, 1526, 'Skills'),
#    (1527, 1529, 'Skills'),
#    (1532, 1537, 'Skills'),
#    (1540, 1547, 'Skills'),
#    (1550, 1553, 'Skills'),
#    (1556, 1559, 'Skills'),
#    (1562, 1571, 'Skills'),
#    (1572, 1578, 'Skills'),
#    (1583, 1589, 'Skills'),
#    (1590, 1593, 'Skills'),
#    (1594, 1598, 'Skills'),
#    (1601, 1608, 'Skills'),
#    (1611, 1619, 'Skills'),
#    (1620, 1623, 'Skills'),
#    (1624, 1632, 'Skills'),
#    (1633, 1635, 'Skills'),
#    (1636, 1645, 'Skills'),
#    (1646, 1656, 'Skills'),
#    (1659, 1665, 'Skills'),
#    (1666, 1669, 'Skills'),
#    (1670, 1674, 'Skills'),
#    (1677, 1681, 'Skills'),
#    (1684, 1690, 'Skills')]})

# %%
import random
import math

def train_test_split(data, test_size, random_state):

    random.Random(random_state).shuffle(data)
    test_idx = len(data) - math.floor(test_size * len(data))
    train_set = data[0: test_idx]
    test_set = data[test_idx: ]

    return train_set, test_set

# %%
train_data, test_data = train_test_split(data, test_size = 0.1, random_state = 42)

# %%
from spacy.training.example import Example

def train_spacy():
    nlp = spacy.blank('en') # create blank Language class
    # create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
    
    if 'ner' not in nlp.pipe_names:
        ner = nlp.add_pipe('ner', last=True)
        
    #add labels
    for _, annotations in train_data:
        for ent in annotations.get('entities'):
            ner.add_label(ent[2])
            
    # get names of other pipes to disable them during training
    other_pipes = [pipe for pipe in nlp.pipe_names if pipe!='ner']
    with nlp.disable_pipes(*other_pipes):
        optimizer = nlp.begin_training()
        for i in range(10):
            print("Startting iteration: " + str(i))
            random.shuffle(train_data)
            losses = {}
            for text, annotations in train_data:
                doc = nlp.make_doc(text)
                example = Example.from_dict(doc, annotations)
                nlp.update(
                    [example],
                    drop=0.2,
                    sgd=optimizer,
                    losses=losses
                )
            print(losses)
    return nlp

# %%
nlp = train_spacy()
# Out:
# Startting iteration: 0
# {'ner': 12714.107547996162}
# Startting iteration: 1
# {'ner': 5185.351196570317}
# Startting iteration: 2
# {'ner': 3936.6018085440624}
# Startting iteration: 3
# {'ner': 3388.3289496835555}
# Startting iteration: 4
# {'ner': 3472.2929171825235}
# Startting iteration: 5
# {'ner': 2989.025504717005}
# Startting iteration: 6
# {'ner': 2873.7848576008696}
# Startting iteration: 7
# {'ner': 2721.5860096061974}
# Startting iteration: 8
# {'ner': 2481.70971136244}
# Startting iteration: 9
# {'ner': 2457.8511689123843}

# %%
from itertools import groupby

def doc_to_bilou(nlp, text):
    
    doc = nlp(text)
    tokens = [(tok.text, tok.idx, tok.ent_type_) for tok in doc]
    entities = []
    for entity, group in groupby(tokens, key=lambda t: t[-1]):
        if not entity:
            continue
        group = list(group)
        _, start_word_idx, _ = group[0]
        last_word, last_word_idx, _ = group[-1]
        end_idx = last_word_idx + len(last_word)
        entities.append((
                start_word_idx,
                end_idx,
                entity
            ))
    #print(entities)
    parse = Example.from_dict(nlp.make_doc(text), {'entities':entities})
    pred_ents = parse.get_aligned_ner()
    
    return pred_ents

# %%
y_test = []
y_pred = []

for text, annots in test_data:
    
    gold = Example.from_dict(nlp.make_doc(text), annots)
    ents = gold.get_aligned_ner()
    pred_ents = doc_to_bilou(nlp, text)
    
    y_test.append(ents)
    y_pred.append(pred_ents)

# %%
from spacy.scorer import Scorer
from spacy.tokens import Doc
from spacy.training.example import Example

def evaluate(nlp, test_data):
    scorer = Scorer()
    example = []
    for text, annots in test_data:
        pred = nlp(text)
        temp = Example.from_dict(pred, annots)
        example.append(temp)
    scores = scorer.score(example)
    return scores

# %%
scores = evaluate(nlp,test_data)

# %%
scores
# Out:
# {'token_acc': 1.0,
#  'token_p': 1.0,
#  'token_r': 1.0,
#  'token_f': 1.0,
#  'sents_p': None,
#  'sents_r': None,
#  'sents_f': None,
#  'tag_acc': None,
#  'pos_acc': None,
#  'morph_acc': None,
#  'morph_micro_p': None,
#  'morph_micro_r': None,
#  'morph_micro_f': None,
#  'morph_per_feat': None,
#  'dep_uas': None,
#  'dep_las': None,
#  'dep_las_per_type': None,
#  'ents_p': 0.6616915422885572,
#  'ents_r': 0.4290322580645161,
#  'ents_f': 0.5205479452054794,
#  'ents_per_type': {'Name': {'p': 0.9545454545454546,
#    'r': 0.9130434782608695,
#    'f': 0.9333333333333332},
#   'Location': {'p': 0.75, 'r': 0.42857142857142855, 'f': 0.5454545454545454},
#   'Email Address': {'p': 0.6842105263157895,
#    'r': 0.7647058823529411,
#    'f': 0.7222222222222222},
#   'Companies worked at': {'p': 0.36666666666666664,
#    'r': 0.30985915492957744,
#    'f': 0.3358778625954198},
#   'Skills': {'p': 0.46153846153846156,
#    'r': 0.20689655172413793,
#    'f': 0.28571428571428575},
#   'Degree': {'p': 0.9545454545454546,
#    'r': 0.7777777777777778,
#    'f': 0.8571428571428572},
#   'College Name': {'p': 0.8333333333333334,
#    'r': 0.45454545454545453,
#    'f': 0.5882352941176471},
#   'Designation': {'p': 0.7407407407407407,
#    'r': 0.4166666666666667,
#    'f': 0.5333333333333333},
#   'Years of Experience': {'p': 0.0, 'r': 0.0, 'f': 0.0},
#   'Graduation Year': {'p': 0.0, 'r': 0.0, 'f': 0.0}},
#  'cats_score': 0.0,
#  'cats_score_desc': 'macro F',
#  'cats_micro_p': 0.0,
#  'cats_micro_r': 0.0,
#  'cats_micro_f': 0.0,
#  'cats_macro_p': 0.0,
#  'cats_macro_r': 0.0,
#  'cats_macro_f': 0.0,
#  'cats_macro_auc': 0.0,
#  'cats_f_per_type': {},
#  'cats_auc_per_type': {}}
